# %%
import os

def walk_through_dir(dir_path):
    for dirpath, dirnames, filenames in os.walk(dir_path):
        num_images = len([f for f in filenames if f.endswith('.png') or f.endswith('.jpg')])
        print(f"There are {len(dirnames)} directories and {num_images} images in '{dirpath}'.")
        for dirname in dirnames:
            print(f"  Subdirectory: {dirname}")

walk_through_dir('data')
# Out:
# There are 657 directories and 0 images in 'data'.
#   Subdirectory: 000
#   Subdirectory: 001
#   Subdirectory: 002
#   Subdirectory: 003
#   Subdirectory: 004
#   Subdirectory: 005
#   Subdirectory: 006
#   Subdirectory: 007
#   Subdirectory: 008
#   Subdirectory: 009
#   Subdirectory: 010
#   Subdirectory: 011
#   Subdirectory: 012
#   Subdirectory: 013
#   Subdirectory: 014
#   Subdirectory: 015
#   Subdirectory: 016
#   Subdirectory: 017
#   Subdirectory: 018
#   Subdirectory: 019
#   Subdirectory: 020
#   Subdirectory: 021
#   Subdirectory: 022
#   Subdirectory: 023
#   Subdirectory: 024
#   Subdirectory: 025
#   Subdirectory: 026
#   Subdirectory: 027
#   Subdirectory: 028
#   Subdirectory: 029
#   Subdirectory: 030
#   Subdirectory: 031
#   Subdirectory: 032
#   Subdirectory: 033
#   Subdirectory: 034
#   Subdirectory: 035
#   Subdirectory: 036
#   Subdirectory: 037
#   Subdirectory: 038
#   Subdirectory: 039
#   Subdirectory: 040
#   Subdirectory: 041
#   Subdirectory: 042
#   Subdirectory: 043
#   Subdirectory: 044
#   Subdirectory: 045
#   Subdirectory: 046
#   Subdirectory: 047
#   Subdirectory: 048
#   Subdirectory: 049
#   Subdirectory: 050
#   Subdirectory: 051
#   Subdirectory: 052
#   Subdirectory: 053
#   Subdirectory: 054
#   Subdirectory: 055
#   Subdirectory: 056
#   Subdirectory: 058
#   Subdirectory: 059
#   Subdirectory: 060
#   Subdirectory: 061
#   Subdirectory: 062
#   Subdirectory: 063
#   Subdirectory: 064
#   Subdirectory: 065
#   Subdirectory: 066
#   Subdirectory: 067
#   Subdirectory: 068
#   Subdirectory: 069
#   Subdirectory: 070
#   Subdirectory: 071
#   Subdirectory: 072
#   Subdirectory: 073
#   Subdirectory: 074
#   Subdirectory: 075
#   Subdirectory: 076
#   Subdirectory: 077
#   Subdirectory: 078
#   Subdirectory: 079
#   Subdirectory: 080
#   Subdirectory: 081
#   Subdirectory: 082
#   Subdirectory: 083
#   Subdirectory: 084
#   Subdirectory: 085
#   Subdirectory: 086
#   Subdirectory: 087
#   Subdirectory: 088
#   Subdirectory: 089
#   Subdirectory: 090
#   Subdirectory: 091
#   Subdirectory: 092
#   Subdirectory: 093
#   Subdirectory: 094
#   Subdirectory: 095
#   Subdirectory: 096
#   Subdirectory: 097
#   Subdirectory: 098
#   Subdirectory: 099
#   Subdirectory: 100
#   Subdirectory: 102
#   Subdirectory: 103
#   Subdirectory: 104
#   Subdirectory: 105
#   Subdirectory: 106
#   Subdirectory: 107
#   Subdirectory: 108
#   Subdirectory: 109
#   Subdirectory: 110
#   Subdirectory: 111
#   Subdirectory: 112
#   Subdirectory: 113
#   Subdirectory: 114
#   Subdirectory: 115
#   Subdirectory: 116
#   Subdirectory: 117
#   Subdirectory: 118
#   Subdirectory: 119
#   Subdirectory: 120
#   Subdirectory: 121
#   Subdirectory: 122
#   Subdirectory: 123
#   Subdirectory: 124
#   Subdirectory: 125
#   Subdirectory: 126
#   Subdirectory: 127
#   Subdirectory: 128
#   Subdirectory: 129
#   Subdirectory: 130
#   Subdirectory: 131
#   Subdirectory: 132
#   Subdirectory: 133
#   Subdirectory: 134
#   Subdirectory: 135
#   Subdirectory: 136
#   Subdirectory: 137
#   Subdirectory: 138
#   Subdirectory: 139
#   Subdirectory: 140
#   Subdirectory: 141
#   Subdirectory: 142
#   Subdirectory: 143
#   Subdirectory: 144
#   Subdirectory: 145
#   Subdirectory: 146
#   Subdirectory: 147
#   Subdirectory: 148
#   Subdirectory: 149
#   Subdirectory: 150
#   Subdirectory: 151
#   Subdirectory: 152
#   Subdirectory: 153
#   Subdirectory: 154
#   Subdirectory: 155
#   Subdirectory: 156
#   Subdirectory: 157
#   Subdirectory: 158
#   Subdirectory: 159
#   Subdirectory: 160
#   Subdirectory: 161
#   Subdirectory: 162
#   Subdirectory: 163
#   Subdirectory: 164
#   Subdirectory: 165
#   Subdirectory: 166
#   Subdirectory: 167
#   Subdirectory: 168
#   Subdirectory: 169
#   Subdirectory: 170
#   Subdirectory: 171
#   Subdirectory: 172
#   Subdirectory: 173
#   Subdirectory: 174
#   Subdirectory: 175
#   Subdirectory: 176
#   Subdirectory: 177
#   Subdirectory: 178
#   Subdirectory: 179
#   Subdirectory: 180
#   Subdirectory: 181
#   Subdirectory: 182
#   Subdirectory: 183
#   Subdirectory: 184
#   Subdirectory: 185
#   Subdirectory: 186
#   Subdirectory: 187
#   Subdirectory: 188
#   Subdirectory: 189
#   Subdirectory: 190
#   Subdirectory: 191
#   Subdirectory: 192
#   Subdirectory: 193
#   Subdirectory: 194
#   Subdirectory: 195
#   Subdirectory: 196
#   Subdirectory: 197
#   Subdirectory: 198
#   Subdirectory: 199
#   Subdirectory: 200
#   Subdirectory: 201
#   Subdirectory: 202
#   Subdirectory: 203
#   Subdirectory: 204
#   Subdirectory: 205
#   Subdirectory: 206
#   Subdirectory: 207
#   Subdirectory: 208
#   Subdirectory: 209
#   Subdirectory: 210
#   Subdirectory: 211
#   Subdirectory: 212
#   Subdirectory: 213
#   Subdirectory: 214
#   Subdirectory: 215
#   Subdirectory: 216
#   Subdirectory: 217
#   Subdirectory: 218
#   Subdirectory: 219
#   Subdirectory: 220
#   Subdirectory: 221
#   Subdirectory: 222
#   Subdirectory: 223
#   Subdirectory: 224
#   Subdirectory: 225
#   Subdirectory: 226
#   Subdirectory: 227
#   Subdirectory: 228
#   Subdirectory: 229
#   Subdirectory: 230
#   Subdirectory: 231
#   Subdirectory: 232
#   Subdirectory: 233
#   Subdirectory: 234
#   Subdirectory: 235
#   Subdirectory: 236
#   Subdirectory: 237
#   Subdirectory: 238
#   Subdirectory: 239
#   Subdirectory: 240
#   Subdirectory: 241
#   Subdirectory: 242
#   Subdirectory: 243
#   Subdirectory: 244
#   Subdirectory: 245
#   Subdirectory: 246
#   Subdirectory: 247
#   Subdirectory: 248
#   Subdirectory: 249
#   Subdirectory: 250
#   Subdirectory: 251
#   Subdirectory: 252
#   Subdirectory: 253
#   Subdirectory: 254
#   Subdirectory: 255
#   Subdirectory: 256
#   Subdirectory: 257
#   Subdirectory: 258
#   Subdirectory: 259
#   Subdirectory: 260
#   Subdirectory: 261
#   Subdirectory: 262
#   Subdirectory: 263
#   Subdirectory: 264
#   Subdirectory: 265
#   Subdirectory: 266
#   Subdirectory: 267
#   Subdirectory: 268
#   Subdirectory: 269
#   Subdirectory: 270
#   Subdirectory: 272
#   Subdirectory: 273
#   Subdirectory: 274
#   Subdirectory: 275
#   Subdirectory: 276
#   Subdirectory: 277
#   Subdirectory: 278
#   Subdirectory: 279
#   Subdirectory: 280
#   Subdirectory: 281
#   Subdirectory: 282
#   Subdirectory: 283
#   Subdirectory: 285
#   Subdirectory: 286
#   Subdirectory: 287
#   Subdirectory: 288
#   Subdirectory: 289
#   Subdirectory: 290
#   Subdirectory: 291
#   Subdirectory: 292
#   Subdirectory: 293
#   Subdirectory: 294
#   Subdirectory: 295
#   Subdirectory: 296
#   Subdirectory: 297
#   Subdirectory: 298
#   Subdirectory: 299
#   Subdirectory: 300
#   Subdirectory: 301
#   Subdirectory: 302
#   Subdirectory: 303
#   Subdirectory: 304
#   Subdirectory: 305
#   Subdirectory: 307
#   Subdirectory: 308
#   Subdirectory: 309
#   Subdirectory: 310
#   Subdirectory: 312
#   Subdirectory: 313
#   Subdirectory: 314
#   Subdirectory: 315
#   Subdirectory: 316
#   Subdirectory: 317
#   Subdirectory: 318
#   Subdirectory: 319
#   Subdirectory: 320
#   Subdirectory: 321
#   Subdirectory: 322
#   Subdirectory: 323
#   Subdirectory: 324
#   Subdirectory: 325
#   Subdirectory: 326
#   Subdirectory: 327
#   Subdirectory: 328
#   Subdirectory: 329
#   Subdirectory: 330
#   Subdirectory: 331
#   Subdirectory: 332
#   Subdirectory: 333
#   Subdirectory: 334
#   Subdirectory: 335
#   Subdirectory: 336
#   Subdirectory: 337
#   Subdirectory: 338
#   Subdirectory: 339
#   Subdirectory: 340
#   Subdirectory: 341
#   Subdirectory: 342
#   Subdirectory: 343
#   Subdirectory: 344
#   Subdirectory: 345
#   Subdirectory: 346
#   Subdirectory: 347
#   Subdirectory: 348
#   Subdirectory: 349
#   Subdirectory: 350
#   Subdirectory: 351
#   Subdirectory: 352
#   Subdirectory: 353
#   Subdirectory: 354
#   Subdirectory: 355
#   Subdirectory: 356
#   Subdirectory: 357
#   Subdirectory: 359
#   Subdirectory: 360
#   Subdirectory: 361
#   Subdirectory: 362
#   Subdirectory: 363
#   Subdirectory: 364
#   Subdirectory: 365
#   Subdirectory: 366
#   Subdirectory: 367
#   Subdirectory: 368
#   Subdirectory: 369
#   Subdirectory: 370
#   Subdirectory: 371
#   Subdirectory: 372
#   Subdirectory: 373
#   Subdirectory: 375
#   Subdirectory: 376
#   Subdirectory: 377
#   Subdirectory: 378
#   Subdirectory: 379
#   Subdirectory: 380
#   Subdirectory: 382
#   Subdirectory: 383
#   Subdirectory: 384
#   Subdirectory: 385
#   Subdirectory: 386
#   Subdirectory: 387
#   Subdirectory: 388
#   Subdirectory: 389
#   Subdirectory: 390
#   Subdirectory: 391
#   Subdirectory: 392
#   Subdirectory: 393
#   Subdirectory: 394
#   Subdirectory: 395
#   Subdirectory: 396
#   Subdirectory: 397
#   Subdirectory: 398
#   Subdirectory: 399
#   Subdirectory: 400
#   Subdirectory: 401
#   Subdirectory: 402
#   Subdirectory: 403
#   Subdirectory: 404
#   Subdirectory: 405
#   Subdirectory: 406
#   Subdirectory: 407
#   Subdirectory: 408
#   Subdirectory: 409
#   Subdirectory: 410
#   Subdirectory: 411
#   Subdirectory: 412
#   Subdirectory: 413
#   Subdirectory: 414
#   Subdirectory: 415
#   Subdirectory: 416
#   Subdirectory: 417
#   Subdirectory: 418
#   Subdirectory: 419
#   Subdirectory: 420
#   Subdirectory: 421
#   Subdirectory: 422
#   Subdirectory: 423
#   Subdirectory: 424
#   Subdirectory: 425
#   Subdirectory: 426
#   Subdirectory: 427
#   Subdirectory: 428
#   Subdirectory: 429
#   Subdirectory: 430
#   Subdirectory: 431
#   Subdirectory: 432
#   Subdirectory: 433
#   Subdirectory: 434
#   Subdirectory: 435
#   Subdirectory: 436
#   Subdirectory: 439
#   Subdirectory: 440
#   Subdirectory: 441
#   Subdirectory: 442
#   Subdirectory: 443
#   Subdirectory: 444
#   Subdirectory: 445
#   Subdirectory: 446
#   Subdirectory: 447
#   Subdirectory: 448
#   Subdirectory: 449
#   Subdirectory: 450
#   Subdirectory: 451
#   Subdirectory: 452
#   Subdirectory: 453
#   Subdirectory: 454
#   Subdirectory: 455
#   Subdirectory: 456
#   Subdirectory: 457
#   Subdirectory: 458
#   Subdirectory: 459
#   Subdirectory: 460
#   Subdirectory: 461
#   Subdirectory: 462
#   Subdirectory: 463
#   Subdirectory: 464
#   Subdirectory: 465
#   Subdirectory: 466
#   Subdirectory: 467
#   Subdirectory: 468
#   Subdirectory: 469
#   Subdirectory: 470
#   Subdirectory: 471
#   Subdirectory: 472
#   Subdirectory: 473
#   Subdirectory: 474
#   Subdirectory: 475
#   Subdirectory: 476
#   Subdirectory: 477
#   Subdirectory: 478
#   Subdirectory: 479
#   Subdirectory: 480
#   Subdirectory: 481
#   Subdirectory: 482
#   Subdirectory: 483
#   Subdirectory: 484
#   Subdirectory: 485
#   Subdirectory: 486
#   Subdirectory: 487
#   Subdirectory: 488
#   Subdirectory: 489
#   Subdirectory: 490
#   Subdirectory: 491
#   Subdirectory: 492
#   Subdirectory: 493
#   Subdirectory: 494
#   Subdirectory: 495
#   Subdirectory: 496
#   Subdirectory: 497
#   Subdirectory: 498
#   Subdirectory: 499
#   Subdirectory: 500
#   Subdirectory: 501
#   Subdirectory: 502
#   Subdirectory: 503
#   Subdirectory: 504
#   Subdirectory: 505
#   Subdirectory: 506
#   Subdirectory: 508
#   Subdirectory: 509
#   Subdirectory: 510
#   Subdirectory: 511
#   Subdirectory: 512
#   Subdirectory: 513
#   Subdirectory: 514
#   Subdirectory: 515
#   Subdirectory: 516
#   Subdirectory: 517
#   Subdirectory: 518
#   Subdirectory: 519
#   Subdirectory: 520
#   Subdirectory: 521
#   Subdirectory: 522
#   Subdirectory: 523
#   Subdirectory: 524
#   Subdirectory: 525
#   Subdirectory: 526
#   Subdirectory: 527
#   Subdirectory: 528
#   Subdirectory: 529
#   Subdirectory: 530
#   Subdirectory: 531
#   Subdirectory: 532
#   Subdirectory: 533
#   Subdirectory: 534
#   Subdirectory: 535
#   Subdirectory: 536
#   Subdirectory: 537
#   Subdirectory: 538
#   Subdirectory: 539
#   Subdirectory: 540
#   Subdirectory: 541
#   Subdirectory: 542
#   Subdirectory: 543
#   Subdirectory: 544
#   Subdirectory: 545
#   Subdirectory: 546
#   Subdirectory: 547
#   Subdirectory: 548
#   Subdirectory: 549
#   Subdirectory: 550
#   Subdirectory: 551
#   Subdirectory: 552
#   Subdirectory: 553
#   Subdirectory: 554
#   Subdirectory: 555
#   Subdirectory: 556
#   Subdirectory: 557
#   Subdirectory: 558
#   Subdirectory: 559
#   Subdirectory: 560
#   Subdirectory: 561
#   Subdirectory: 562
#   Subdirectory: 563
#   Subdirectory: 564
#   Subdirectory: 565
#   Subdirectory: 566
#   Subdirectory: 567
#   Subdirectory: 568
#   Subdirectory: 569
#   Subdirectory: 570
#   Subdirectory: 571
#   Subdirectory: 572
#   Subdirectory: 573
#   Subdirectory: 574
#   Subdirectory: 575
#   Subdirectory: 576
#   Subdirectory: 577
#   Subdirectory: 578
#   Subdirectory: 579
#   Subdirectory: 580
#   Subdirectory: 581
#   Subdirectory: 582
#   Subdirectory: 583
#   Subdirectory: 584
#   Subdirectory: 585
#   Subdirectory: 586
#   Subdirectory: 587
#   Subdirectory: 588
#   Subdirectory: 589
#   Subdirectory: 590
#   Subdirectory: 591
#   Subdirectory: 592
#   Subdirectory: 593
#   Subdirectory: 594
#   Subdirectory: 595
#   Subdirectory: 596
#   Subdirectory: 597
#   Subdirectory: 598
#   Subdirectory: 599
#   Subdirectory: 600
#   Subdirectory: 601
#   Subdirectory: 602
#   Subdirectory: 603
#   Subdirectory: 604
#   Subdirectory: 605
#   Subdirectory: 606
#   Subdirectory: 607
#   Subdirectory: 608
#   Subdirectory: 609
#   Subdirectory: 610
#   Subdirectory: 611
#   Subdirectory: 612
#   Subdirectory: 613
#   Subdirectory: 614
#   Subdirectory: 615
#   Subdirectory: 616
#   Subdirectory: 617
#   Subdirectory: 618
#   Subdirectory: 619
#   Subdirectory: 620
#   Subdirectory: 621
#   Subdirectory: 622
#   Subdirectory: 623
#   Subdirectory: 624
#   Subdirectory: 625
#   Subdirectory: 626
#   Subdirectory: 627
#   Subdirectory: 628
#   Subdirectory: 629
#   Subdirectory: 630
#   Subdirectory: 631
#   Subdirectory: 632
#   Subdirectory: 633
#   Subdirectory: 634
#   Subdirectory: 635
#   Subdirectory: 636
#   Subdirectory: 637
#   Subdirectory: 638
#   Subdirectory: 639
#   Subdirectory: 640
#   Subdirectory: 641
#   Subdirectory: 642
#   Subdirectory: 643
#   Subdirectory: 644
#   Subdirectory: 645
#   Subdirectory: 647
#   Subdirectory: 648
#   Subdirectory: 649
#   Subdirectory: 650
#   Subdirectory: 651
#   Subdirectory: 652
#   Subdirectory: 653
#   Subdirectory: 654
#   Subdirectory: 655
#   Subdirectory: 658
#   Subdirectory: 659
#   Subdirectory: 660
#   Subdirectory: 661
#   Subdirectory: 662
#   Subdirectory: 663
#   Subdirectory: 664
#   Subdirectory: 665
#   Subdirectory: 666
#   Subdirectory: 667
#   Subdirectory: 668
#   Subdirectory: 669
#   Subdirectory: 670
#   Subdirectory: 671
# There are 0 directories and 59 images in 'data\000'.
# There are 0 directories and 2 images in 'data\001'.
# There are 0 directories and 1 images in 'data\002'.
# There are 0 directories and 2 images in 'data\003'.
# There are 0 directories and 1 images in 'data\004'.
# There are 0 directories and 2 images in 'data\005'.
# There are 0 directories and 1 images in 'data\006'.
# There are 0 directories and 2 images in 'data\007'.
# There are 0 directories and 2 images in 'data\008'.
# There are 0 directories and 2 images in 'data\009'.
# There are 0 directories and 2 images in 'data\010'.
# There are 0 directories and 2 images in 'data\011'.
# There are 0 directories and 2 images in 'data\012'.
# There are 0 directories and 3 images in 'data\013'.
# There are 0 directories and 2 images in 'data\014'.
# There are 0 directories and 1 images in 'data\015'.
# There are 0 directories and 3 images in 'data\016'.
# There are 0 directories and 3 images in 'data\017'.
# There are 0 directories and 2 images in 'data\018'.
# There are 0 directories and 3 images in 'data\019'.
# There are 0 directories and 1 images in 'data\020'.
# There are 0 directories and 1 images in 'data\021'.
# There are 0 directories and 1 images in 'data\022'.
# There are 0 directories and 1 images in 'data\023'.
# There are 0 directories and 1 images in 'data\024'.
# There are 0 directories and 5 images in 'data\025'.
# There are 0 directories and 5 images in 'data\026'.
# There are 0 directories and 1 images in 'data\027'.
# There are 0 directories and 1 images in 'data\028'.
# There are 0 directories and 1 images in 'data\029'.
# There are 0 directories and 1 images in 'data\030'.
# There are 0 directories and 1 images in 'data\031'.
# There are 0 directories and 1 images in 'data\032'.
# There are 0 directories and 1 images in 'data\033'.
# There are 0 directories and 1 images in 'data\034'.
# There are 0 directories and 1 images in 'data\035'.
# There are 0 directories and 1 images in 'data\036'.
# There are 0 directories and 5 images in 'data\037'.
# There are 0 directories and 1 images in 'data\038'.
# There are 0 directories and 1 images in 'data\039'.
# There are 0 directories and 1 images in 'data\040'.
# There are 0 directories and 1 images in 'data\041'.
# There are 0 directories and 1 images in 'data\042'.
# There are 0 directories and 1 images in 'data\043'.
# There are 0 directories and 1 images in 'data\044'.
# There are 0 directories and 1 images in 'data\045'.
# There are 0 directories and 1 images in 'data\046'.
# There are 0 directories and 1 images in 'data\047'.
# There are 0 directories and 1 images in 'data\048'.
# There are 0 directories and 1 images in 'data\049'.
# There are 0 directories and 1 images in 'data\050'.
# There are 0 directories and 1 images in 'data\051'.
# There are 0 directories and 1 images in 'data\052'.
# There are 0 directories and 1 images in 'data\053'.
# There are 0 directories and 1 images in 'data\054'.
# There are 0 directories and 1 images in 'data\055'.
# There are 0 directories and 1 images in 'data\056'.
# There are 0 directories and 4 images in 'data\058'.
# There are 0 directories and 4 images in 'data\059'.
# There are 0 directories and 4 images in 'data\060'.
# There are 0 directories and 4 images in 'data\061'.
# There are 0 directories and 3 images in 'data\062'.
# There are 0 directories and 3 images in 'data\063'.
# There are 0 directories and 4 images in 'data\064'.
# There are 0 directories and 2 images in 'data\065'.
# There are 0 directories and 2 images in 'data\066'.
# There are 0 directories and 1 images in 'data\067'.
# There are 0 directories and 1 images in 'data\068'.
# There are 0 directories and 1 images in 'data\069'.
# There are 0 directories and 1 images in 'data\070'.
# There are 0 directories and 1 images in 'data\071'.
# There are 0 directories and 1 images in 'data\072'.
# There are 0 directories and 1 images in 'data\073'.
# There are 0 directories and 1 images in 'data\074'.
# There are 0 directories and 1 images in 'data\075'.
# There are 0 directories and 1 images in 'data\076'.
# There are 0 directories and 1 images in 'data\077'.
# There are 0 directories and 1 images in 'data\078'.
# There are 0 directories and 1 images in 'data\079'.
# There are 0 directories and 1 images in 'data\080'.
# There are 0 directories and 2 images in 'data\081'.
# There are 0 directories and 1 images in 'data\082'.
# There are 0 directories and 1 images in 'data\083'.
# There are 0 directories and 2 images in 'data\084'.
# There are 0 directories and 6 images in 'data\085'.
# There are 0 directories and 1 images in 'data\086'.
# There are 0 directories and 3 images in 'data\087'.
# There are 0 directories and 3 images in 'data\088'.
# There are 0 directories and 3 images in 'data\089'.
# There are 0 directories and 3 images in 'data\090'.
# There are 0 directories and 2 images in 'data\091'.
# There are 0 directories and 3 images in 'data\092'.
# There are 0 directories and 3 images in 'data\093'.
# There are 0 directories and 3 images in 'data\094'.
# There are 0 directories and 2 images in 'data\095'.
# There are 0 directories and 1 images in 'data\096'.
# There are 0 directories and 1 images in 'data\097'.
# There are 0 directories and 1 images in 'data\098'.
# There are 0 directories and 1 images in 'data\099'.
# There are 0 directories and 1 images in 'data\100'.
# There are 0 directories and 2 images in 'data\102'.
# There are 0 directories and 1 images in 'data\103'.
# There are 0 directories and 1 images in 'data\104'.
# There are 0 directories and 1 images in 'data\105'.
# There are 0 directories and 1 images in 'data\106'.
# There are 0 directories and 4 images in 'data\107'.
# There are 0 directories and 4 images in 'data\108'.
# There are 0 directories and 4 images in 'data\109'.
# There are 0 directories and 4 images in 'data\110'.
# There are 0 directories and 4 images in 'data\111'.
# There are 0 directories and 4 images in 'data\112'.
# There are 0 directories and 4 images in 'data\113'.
# There are 0 directories and 4 images in 'data\114'.
# There are 0 directories and 1 images in 'data\115'.
# There are 0 directories and 1 images in 'data\116'.
# There are 0 directories and 4 images in 'data\117'.
# There are 0 directories and 7 images in 'data\118'.
# There are 0 directories and 2 images in 'data\119'.
# There are 0 directories and 1 images in 'data\120'.
# There are 0 directories and 2 images in 'data\121'.
# There are 0 directories and 1 images in 'data\122'.
# There are 0 directories and 5 images in 'data\123'.
# There are 0 directories and 4 images in 'data\124'.
# There are 0 directories and 5 images in 'data\125'.
# There are 0 directories and 5 images in 'data\126'.
# There are 0 directories and 3 images in 'data\127'.
# There are 0 directories and 5 images in 'data\128'.
# There are 0 directories and 4 images in 'data\129'.
# There are 0 directories and 5 images in 'data\130'.
# There are 0 directories and 4 images in 'data\131'.
# There are 0 directories and 4 images in 'data\132'.
# There are 0 directories and 5 images in 'data\133'.
# There are 0 directories and 2 images in 'data\134'.
# There are 0 directories and 2 images in 'data\135'.
# There are 0 directories and 1 images in 'data\136'.
# There are 0 directories and 1 images in 'data\137'.
# There are 0 directories and 1 images in 'data\138'.
# There are 0 directories and 2 images in 'data\139'.
# There are 0 directories and 2 images in 'data\140'.
# There are 0 directories and 1 images in 'data\141'.
# There are 0 directories and 1 images in 'data\142'.
# There are 0 directories and 1 images in 'data\143'.
# There are 0 directories and 1 images in 'data\144'.
# There are 0 directories and 1 images in 'data\145'.
# There are 0 directories and 1 images in 'data\146'.
# There are 0 directories and 1 images in 'data\147'.
# There are 0 directories and 1 images in 'data\148'.
# There are 0 directories and 1 images in 'data\149'.
# There are 0 directories and 10 images in 'data\150'.
# There are 0 directories and 10 images in 'data\151'.
# There are 0 directories and 10 images in 'data\152'.
# There are 0 directories and 10 images in 'data\153'.
# There are 0 directories and 10 images in 'data\154'.
# There are 0 directories and 9 images in 'data\155'.
# There are 0 directories and 1 images in 'data\156'.
# There are 0 directories and 2 images in 'data\157'.
# There are 0 directories and 3 images in 'data\158'.
# There are 0 directories and 2 images in 'data\159'.
# There are 0 directories and 2 images in 'data\160'.
# There are 0 directories and 2 images in 'data\161'.
# There are 0 directories and 2 images in 'data\162'.
# There are 0 directories and 2 images in 'data\163'.
# There are 0 directories and 2 images in 'data\164'.
# There are 0 directories and 2 images in 'data\165'.
# There are 0 directories and 2 images in 'data\166'.
# There are 0 directories and 1 images in 'data\167'.
# There are 0 directories and 2 images in 'data\168'.
# There are 0 directories and 2 images in 'data\169'.
# There are 0 directories and 2 images in 'data\170'.
# There are 0 directories and 2 images in 'data\171'.
# There are 0 directories and 2 images in 'data\172'.
# There are 0 directories and 5 images in 'data\173'.
# There are 0 directories and 5 images in 'data\174'.
# There are 0 directories and 2 images in 'data\175'.
# There are 0 directories and 1 images in 'data\176'.
# There are 0 directories and 2 images in 'data\177'.
# There are 0 directories and 2 images in 'data\178'.
# There are 0 directories and 2 images in 'data\179'.
# There are 0 directories and 2 images in 'data\180'.
# There are 0 directories and 3 images in 'data\181'.
# There are 0 directories and 1 images in 'data\182'.
# There are 0 directories and 1 images in 'data\183'.
# There are 0 directories and 2 images in 'data\184'.
# There are 0 directories and 2 images in 'data\185'.
# There are 0 directories and 2 images in 'data\186'.
# There are 0 directories and 2 images in 'data\187'.
# There are 0 directories and 2 images in 'data\188'.
# There are 0 directories and 1 images in 'data\189'.
# There are 0 directories and 2 images in 'data\190'.
# There are 0 directories and 1 images in 'data\191'.
# There are 0 directories and 2 images in 'data\192'.
# There are 0 directories and 4 images in 'data\193'.
# There are 0 directories and 2 images in 'data\194'.
# There are 0 directories and 2 images in 'data\195'.
# There are 0 directories and 1 images in 'data\196'.
# There are 0 directories and 2 images in 'data\197'.
# There are 0 directories and 2 images in 'data\198'.
# There are 0 directories and 4 images in 'data\199'.
# There are 0 directories and 1 images in 'data\200'.
# There are 0 directories and 1 images in 'data\201'.
# There are 0 directories and 5 images in 'data\202'.
# There are 0 directories and 5 images in 'data\203'.
# There are 0 directories and 5 images in 'data\204'.
# There are 0 directories and 5 images in 'data\205'.
# There are 0 directories and 5 images in 'data\206'.
# There are 0 directories and 5 images in 'data\207'.
# There are 0 directories and 5 images in 'data\208'.
# There are 0 directories and 7 images in 'data\209'.
# There are 0 directories and 2 images in 'data\210'.
# There are 0 directories and 2 images in 'data\211'.
# There are 0 directories and 3 images in 'data\212'.
# There are 0 directories and 3 images in 'data\213'.
# There are 0 directories and 2 images in 'data\214'.
# There are 0 directories and 2 images in 'data\215'.
# There are 0 directories and 2 images in 'data\216'.
# There are 0 directories and 3 images in 'data\217'.
# There are 0 directories and 1 images in 'data\218'.
# There are 0 directories and 1 images in 'data\219'.
# There are 0 directories and 1 images in 'data\220'.
# There are 0 directories and 1 images in 'data\221'.
# There are 0 directories and 1 images in 'data\222'.
# There are 0 directories and 1 images in 'data\223'.
# There are 0 directories and 1 images in 'data\224'.
# There are 0 directories and 1 images in 'data\225'.
# There are 0 directories and 1 images in 'data\226'.
# There are 0 directories and 1 images in 'data\227'.
# There are 0 directories and 1 images in 'data\228'.
# There are 0 directories and 1 images in 'data\229'.
# There are 0 directories and 2 images in 'data\230'.
# There are 0 directories and 2 images in 'data\231'.
# There are 0 directories and 2 images in 'data\232'.
# There are 0 directories and 2 images in 'data\233'.
# There are 0 directories and 2 images in 'data\234'.
# There are 0 directories and 2 images in 'data\235'.
# There are 0 directories and 1 images in 'data\236'.
# There are 0 directories and 2 images in 'data\237'.
# There are 0 directories and 1 images in 'data\238'.
# There are 0 directories and 4 images in 'data\239'.
# There are 0 directories and 2 images in 'data\240'.
# There are 0 directories and 4 images in 'data\241'.
# There are 0 directories and 3 images in 'data\242'.
# There are 0 directories and 3 images in 'data\243'.
# There are 0 directories and 1 images in 'data\244'.
# There are 0 directories and 1 images in 'data\245'.
# There are 0 directories and 4 images in 'data\246'.
# There are 0 directories and 5 images in 'data\247'.
# There are 0 directories and 5 images in 'data\248'.
# There are 0 directories and 1 images in 'data\249'.
# There are 0 directories and 2 images in 'data\250'.
# There are 0 directories and 1 images in 'data\251'.
# There are 0 directories and 1 images in 'data\252'.
# There are 0 directories and 1 images in 'data\253'.
# There are 0 directories and 2 images in 'data\254'.
# There are 0 directories and 1 images in 'data\255'.
# There are 0 directories and 2 images in 'data\256'.
# There are 0 directories and 1 images in 'data\257'.
# There are 0 directories and 1 images in 'data\258'.
# There are 0 directories and 2 images in 'data\259'.
# There are 0 directories and 1 images in 'data\260'.
# There are 0 directories and 1 images in 'data\261'.
# There are 0 directories and 1 images in 'data\262'.
# There are 0 directories and 1 images in 'data\263'.
# There are 0 directories and 1 images in 'data\264'.
# There are 0 directories and 1 images in 'data\265'.
# There are 0 directories and 1 images in 'data\266'.
# There are 0 directories and 1 images in 'data\267'.
# There are 0 directories and 1 images in 'data\268'.
# There are 0 directories and 1 images in 'data\269'.
# There are 0 directories and 1 images in 'data\270'.
# There are 0 directories and 3 images in 'data\272'.
# There are 0 directories and 5 images in 'data\273'.
# There are 0 directories and 5 images in 'data\274'.
# There are 0 directories and 2 images in 'data\275'.
# There are 0 directories and 2 images in 'data\276'.
# There are 0 directories and 2 images in 'data\277'.
# There are 0 directories and 2 images in 'data\278'.
# There are 0 directories and 2 images in 'data\279'.
# There are 0 directories and 2 images in 'data\280'.
# There are 0 directories and 2 images in 'data\281'.
# There are 0 directories and 2 images in 'data\282'.
# There are 0 directories and 2 images in 'data\283'.
# There are 0 directories and 5 images in 'data\285'.
# There are 0 directories and 4 images in 'data\286'.
# There are 0 directories and 5 images in 'data\287'.
# There are 0 directories and 5 images in 'data\288'.
# There are 0 directories and 5 images in 'data\289'.
# There are 0 directories and 1 images in 'data\290'.
# There are 0 directories and 4 images in 'data\291'.
# There are 0 directories and 5 images in 'data\292'.
# There are 0 directories and 5 images in 'data\293'.
# There are 0 directories and 4 images in 'data\294'.
# There are 0 directories and 2 images in 'data\295'.
# There are 0 directories and 3 images in 'data\296'.
# There are 0 directories and 3 images in 'data\297'.
# There are 0 directories and 3 images in 'data\298'.
# There are 0 directories and 3 images in 'data\299'.
# There are 0 directories and 3 images in 'data\300'.
# There are 0 directories and 2 images in 'data\301'.
# There are 0 directories and 1 images in 'data\302'.
# There are 0 directories and 1 images in 'data\303'.
# There are 0 directories and 1 images in 'data\304'.
# There are 0 directories and 1 images in 'data\305'.
# There are 0 directories and 1 images in 'data\307'.
# There are 0 directories and 1 images in 'data\308'.
# There are 0 directories and 1 images in 'data\309'.
# There are 0 directories and 1 images in 'data\310'.
# There are 0 directories and 1 images in 'data\312'.
# There are 0 directories and 1 images in 'data\313'.
# There are 0 directories and 1 images in 'data\314'.
# There are 0 directories and 7 images in 'data\315'.
# There are 0 directories and 1 images in 'data\316'.
# There are 0 directories and 1 images in 'data\317'.
# There are 0 directories and 1 images in 'data\318'.
# There are 0 directories and 1 images in 'data\319'.
# There are 0 directories and 2 images in 'data\320'.
# There are 0 directories and 2 images in 'data\321'.
# There are 0 directories and 1 images in 'data\322'.
# There are 0 directories and 1 images in 'data\323'.
# There are 0 directories and 2 images in 'data\324'.
# There are 0 directories and 2 images in 'data\325'.
# There are 0 directories and 1 images in 'data\326'.
# There are 0 directories and 1 images in 'data\327'.
# There are 0 directories and 2 images in 'data\328'.
# There are 0 directories and 2 images in 'data\329'.
# There are 0 directories and 4 images in 'data\330'.
# There are 0 directories and 1 images in 'data\331'.
# There are 0 directories and 8 images in 'data\332'.
# There are 0 directories and 9 images in 'data\333'.
# There are 0 directories and 9 images in 'data\334'.
# There are 0 directories and 8 images in 'data\335'.
# There are 0 directories and 9 images in 'data\336'.
# There are 0 directories and 9 images in 'data\337'.
# There are 0 directories and 9 images in 'data\338'.
# There are 0 directories and 9 images in 'data\339'.
# There are 0 directories and 9 images in 'data\340'.
# There are 0 directories and 9 images in 'data\341'.
# There are 0 directories and 9 images in 'data\342'.
# There are 0 directories and 9 images in 'data\343'.
# There are 0 directories and 9 images in 'data\344'.
# There are 0 directories and 9 images in 'data\345'.
# There are 0 directories and 9 images in 'data\346'.
# There are 0 directories and 9 images in 'data\347'.
# There are 0 directories and 9 images in 'data\348'.
# There are 0 directories and 9 images in 'data\349'.
# There are 0 directories and 4 images in 'data\350'.
# There are 0 directories and 5 images in 'data\351'.
# There are 0 directories and 5 images in 'data\352'.
# There are 0 directories and 5 images in 'data\353'.
# There are 0 directories and 5 images in 'data\354'.
# There are 0 directories and 5 images in 'data\355'.
# There are 0 directories and 2 images in 'data\356'.
# There are 0 directories and 3 images in 'data\357'.
# There are 0 directories and 1 images in 'data\359'.
# There are 0 directories and 1 images in 'data\360'.
# There are 0 directories and 1 images in 'data\361'.
# There are 0 directories and 1 images in 'data\362'.
# There are 0 directories and 1 images in 'data\363'.
# There are 0 directories and 2 images in 'data\364'.
# There are 0 directories and 1 images in 'data\365'.
# There are 0 directories and 1 images in 'data\366'.
# There are 0 directories and 1 images in 'data\367'.
# There are 0 directories and 1 images in 'data\368'.
# There are 0 directories and 1 images in 'data\369'.
# There are 0 directories and 1 images in 'data\370'.
# There are 0 directories and 1 images in 'data\371'.
# There are 0 directories and 1 images in 'data\372'.
# There are 0 directories and 1 images in 'data\373'.
# There are 0 directories and 1 images in 'data\375'.
# There are 0 directories and 1 images in 'data\376'.
# There are 0 directories and 1 images in 'data\377'.
# There are 0 directories and 1 images in 'data\378'.
# There are 0 directories and 2 images in 'data\379'.
# There are 0 directories and 2 images in 'data\380'.
# There are 0 directories and 2 images in 'data\382'.
# There are 0 directories and 2 images in 'data\383'.
# There are 0 directories and 10 images in 'data\384'.
# There are 0 directories and 5 images in 'data\385'.
# There are 0 directories and 5 images in 'data\386'.
# There are 0 directories and 5 images in 'data\387'.
# There are 0 directories and 3 images in 'data\388'.
# There are 0 directories and 5 images in 'data\389'.
# There are 0 directories and 5 images in 'data\390'.
# There are 0 directories and 5 images in 'data\391'.
# There are 0 directories and 4 images in 'data\392'.
# There are 0 directories and 5 images in 'data\393'.
# There are 0 directories and 2 images in 'data\394'.
# There are 0 directories and 1 images in 'data\395'.
# There are 0 directories and 1 images in 'data\396'.
# There are 0 directories and 1 images in 'data\397'.
# There are 0 directories and 1 images in 'data\398'.
# There are 0 directories and 1 images in 'data\399'.
# There are 0 directories and 1 images in 'data\400'.
# There are 0 directories and 1 images in 'data\401'.
# There are 0 directories and 1 images in 'data\402'.
# There are 0 directories and 2 images in 'data\403'.
# There are 0 directories and 1 images in 'data\404'.
# There are 0 directories and 2 images in 'data\405'.
# There are 0 directories and 1 images in 'data\406'.
# There are 0 directories and 1 images in 'data\407'.
# There are 0 directories and 2 images in 'data\408'.
# There are 0 directories and 2 images in 'data\409'.
# There are 0 directories and 1 images in 'data\410'.
# There are 0 directories and 1 images in 'data\411'.
# There are 0 directories and 1 images in 'data\412'.
# There are 0 directories and 1 images in 'data\413'.
# There are 0 directories and 2 images in 'data\414'.
# There are 0 directories and 7 images in 'data\415'.
# There are 0 directories and 1 images in 'data\416'.
# There are 0 directories and 1 images in 'data\417'.
# There are 0 directories and 1 images in 'data\418'.
# There are 0 directories and 1 images in 'data\419'.
# There are 0 directories and 2 images in 'data\420'.
# There are 0 directories and 1 images in 'data\421'.
# There are 0 directories and 1 images in 'data\422'.
# There are 0 directories and 1 images in 'data\423'.
# There are 0 directories and 1 images in 'data\424'.
# There are 0 directories and 1 images in 'data\425'.
# There are 0 directories and 1 images in 'data\426'.
# There are 0 directories and 1 images in 'data\427'.
# There are 0 directories and 1 images in 'data\428'.
# There are 0 directories and 1 images in 'data\429'.
# There are 0 directories and 1 images in 'data\430'.
# There are 0 directories and 1 images in 'data\431'.
# There are 0 directories and 1 images in 'data\432'.
# There are 0 directories and 1 images in 'data\433'.
# There are 0 directories and 1 images in 'data\434'.
# There are 0 directories and 1 images in 'data\435'.
# There are 0 directories and 1 images in 'data\436'.
# There are 0 directories and 2 images in 'data\439'.
# There are 0 directories and 1 images in 'data\440'.
# There are 0 directories and 1 images in 'data\441'.
# There are 0 directories and 2 images in 'data\442'.
# There are 0 directories and 2 images in 'data\443'.
# There are 0 directories and 2 images in 'data\444'.
# There are 0 directories and 2 images in 'data\445'.
# There are 0 directories and 2 images in 'data\446'.
# There are 0 directories and 2 images in 'data\447'.
# There are 0 directories and 2 images in 'data\448'.
# There are 0 directories and 2 images in 'data\449'.
# There are 0 directories and 2 images in 'data\450'.
# There are 0 directories and 2 images in 'data\451'.
# There are 0 directories and 2 images in 'data\452'.
# There are 0 directories and 2 images in 'data\453'.
# There are 0 directories and 5 images in 'data\454'.
# There are 0 directories and 5 images in 'data\455'.
# There are 0 directories and 5 images in 'data\456'.
# There are 0 directories and 1 images in 'data\457'.
# There are 0 directories and 3 images in 'data\458'.
# There are 0 directories and 1 images in 'data\459'.
# There are 0 directories and 1 images in 'data\460'.
# There are 0 directories and 1 images in 'data\461'.
# There are 0 directories and 1 images in 'data\462'.
# There are 0 directories and 1 images in 'data\463'.
# There are 0 directories and 1 images in 'data\464'.
# There are 0 directories and 1 images in 'data\465'.
# There are 0 directories and 1 images in 'data\466'.
# There are 0 directories and 1 images in 'data\467'.
# There are 0 directories and 1 images in 'data\468'.
# There are 0 directories and 1 images in 'data\469'.
# There are 0 directories and 1 images in 'data\470'.
# There are 0 directories and 1 images in 'data\471'.
# There are 0 directories and 1 images in 'data\472'.
# There are 0 directories and 1 images in 'data\473'.
# There are 0 directories and 1 images in 'data\474'.
# There are 0 directories and 1 images in 'data\475'.
# There are 0 directories and 1 images in 'data\476'.
# There are 0 directories and 1 images in 'data\477'.
# There are 0 directories and 1 images in 'data\478'.
# There are 0 directories and 1 images in 'data\479'.
# There are 0 directories and 2 images in 'data\480'.
# There are 0 directories and 2 images in 'data\481'.
# There are 0 directories and 2 images in 'data\482'.
# There are 0 directories and 2 images in 'data\483'.
# There are 0 directories and 2 images in 'data\484'.
# There are 0 directories and 1 images in 'data\485'.
# There are 0 directories and 2 images in 'data\486'.
# There are 0 directories and 2 images in 'data\487'.
# There are 0 directories and 2 images in 'data\488'.
# There are 0 directories and 2 images in 'data\489'.
# There are 0 directories and 2 images in 'data\490'.
# There are 0 directories and 2 images in 'data\491'.
# There are 0 directories and 2 images in 'data\492'.
# There are 0 directories and 2 images in 'data\493'.
# There are 0 directories and 2 images in 'data\494'.
# There are 0 directories and 3 images in 'data\495'.
# There are 0 directories and 4 images in 'data\496'.
# There are 0 directories and 4 images in 'data\497'.
# There are 0 directories and 5 images in 'data\498'.
# There are 0 directories and 1 images in 'data\499'.
# There are 0 directories and 1 images in 'data\500'.
# There are 0 directories and 1 images in 'data\501'.
# There are 0 directories and 1 images in 'data\502'.
# There are 0 directories and 1 images in 'data\503'.
# There are 0 directories and 1 images in 'data\504'.
# There are 0 directories and 1 images in 'data\505'.
# There are 0 directories and 1 images in 'data\506'.
# There are 0 directories and 1 images in 'data\508'.
# There are 0 directories and 1 images in 'data\509'.
# There are 0 directories and 1 images in 'data\510'.
# There are 0 directories and 1 images in 'data\511'.
# There are 0 directories and 1 images in 'data\512'.
# There are 0 directories and 2 images in 'data\513'.
# There are 0 directories and 2 images in 'data\514'.
# There are 0 directories and 1 images in 'data\515'.
# There are 0 directories and 1 images in 'data\516'.
# There are 0 directories and 1 images in 'data\517'.
# There are 0 directories and 1 images in 'data\518'.
# There are 0 directories and 1 images in 'data\519'.
# There are 0 directories and 1 images in 'data\520'.
# There are 0 directories and 1 images in 'data\521'.
# There are 0 directories and 1 images in 'data\522'.
# There are 0 directories and 1 images in 'data\523'.
# There are 0 directories and 1 images in 'data\524'.
# There are 0 directories and 1 images in 'data\525'.
# There are 0 directories and 1 images in 'data\526'.
# There are 0 directories and 2 images in 'data\527'.
# There are 0 directories and 1 images in 'data\528'.
# There are 0 directories and 1 images in 'data\529'.
# There are 0 directories and 1 images in 'data\530'.
# There are 0 directories and 1 images in 'data\531'.
# There are 0 directories and 1 images in 'data\532'.
# There are 0 directories and 1 images in 'data\533'.
# There are 0 directories and 1 images in 'data\534'.
# There are 0 directories and 1 images in 'data\535'.
# There are 0 directories and 1 images in 'data\536'.
# There are 0 directories and 1 images in 'data\537'.
# There are 0 directories and 1 images in 'data\538'.
# There are 0 directories and 1 images in 'data\539'.
# There are 0 directories and 1 images in 'data\540'.
# There are 0 directories and 1 images in 'data\541'.
# There are 0 directories and 2 images in 'data\542'.
# There are 0 directories and 1 images in 'data\543'.
# There are 0 directories and 5 images in 'data\544'.
# There are 0 directories and 4 images in 'data\545'.
# There are 0 directories and 5 images in 'data\546'.
# There are 0 directories and 5 images in 'data\547'.
# There are 0 directories and 5 images in 'data\548'.
# There are 0 directories and 5 images in 'data\549'.
# There are 0 directories and 5 images in 'data\550'.
# There are 0 directories and 10 images in 'data\551'.
# There are 0 directories and 10 images in 'data\552'.
# There are 0 directories and 2 images in 'data\553'.
# There are 0 directories and 1 images in 'data\554'.
# There are 0 directories and 3 images in 'data\555'.
# There are 0 directories and 1 images in 'data\556'.
# There are 0 directories and 1 images in 'data\557'.
# There are 0 directories and 1 images in 'data\558'.
# There are 0 directories and 2 images in 'data\559'.
# There are 0 directories and 2 images in 'data\560'.
# There are 0 directories and 2 images in 'data\561'.
# There are 0 directories and 2 images in 'data\562'.
# There are 0 directories and 2 images in 'data\563'.
# There are 0 directories and 1 images in 'data\564'.
# There are 0 directories and 1 images in 'data\565'.
# There are 0 directories and 1 images in 'data\566'.
# There are 0 directories and 6 images in 'data\567'.
# There are 0 directories and 1 images in 'data\568'.
# There are 0 directories and 1 images in 'data\569'.
# There are 0 directories and 1 images in 'data\570'.
# There are 0 directories and 1 images in 'data\571'.
# There are 0 directories and 1 images in 'data\572'.
# There are 0 directories and 1 images in 'data\573'.
# There are 0 directories and 1 images in 'data\574'.
# There are 0 directories and 1 images in 'data\575'.
# There are 0 directories and 1 images in 'data\576'.
# There are 0 directories and 2 images in 'data\577'.
# There are 0 directories and 1 images in 'data\578'.
# There are 0 directories and 1 images in 'data\579'.
# There are 0 directories and 1 images in 'data\580'.
# There are 0 directories and 1 images in 'data\581'.
# There are 0 directories and 5 images in 'data\582'.
# There are 0 directories and 5 images in 'data\583'.
# There are 0 directories and 5 images in 'data\584'.
# There are 0 directories and 5 images in 'data\585'.
# There are 0 directories and 4 images in 'data\586'.
# There are 0 directories and 4 images in 'data\587'.
# There are 0 directories and 10 images in 'data\588'.
# There are 0 directories and 1 images in 'data\589'.
# There are 0 directories and 1 images in 'data\590'.
# There are 0 directories and 1 images in 'data\591'.
# There are 0 directories and 1 images in 'data\592'.
# There are 0 directories and 1 images in 'data\593'.
# There are 0 directories and 1 images in 'data\594'.
# There are 0 directories and 1 images in 'data\595'.
# There are 0 directories and 1 images in 'data\596'.
# There are 0 directories and 1 images in 'data\597'.
# There are 0 directories and 2 images in 'data\598'.
# There are 0 directories and 2 images in 'data\599'.
# There are 0 directories and 1 images in 'data\600'.
# There are 0 directories and 1 images in 'data\601'.
# There are 0 directories and 1 images in 'data\602'.
# There are 0 directories and 1 images in 'data\603'.
# There are 0 directories and 1 images in 'data\604'.
# There are 0 directories and 1 images in 'data\605'.
# There are 0 directories and 1 images in 'data\606'.
# There are 0 directories and 1 images in 'data\607'.
# There are 0 directories and 1 images in 'data\608'.
# There are 0 directories and 1 images in 'data\609'.
# There are 0 directories and 1 images in 'data\610'.
# There are 0 directories and 1 images in 'data\611'.
# There are 0 directories and 1 images in 'data\612'.
# There are 0 directories and 1 images in 'data\613'.
# There are 0 directories and 1 images in 'data\614'.
# There are 0 directories and 1 images in 'data\615'.
# There are 0 directories and 1 images in 'data\616'.
# There are 0 directories and 1 images in 'data\617'.
# There are 0 directories and 1 images in 'data\618'.
# There are 0 directories and 1 images in 'data\619'.
# There are 0 directories and 1 images in 'data\620'.
# There are 0 directories and 1 images in 'data\621'.
# There are 0 directories and 1 images in 'data\622'.
# There are 0 directories and 1 images in 'data\623'.
# There are 0 directories and 1 images in 'data\624'.
# There are 0 directories and 1 images in 'data\625'.
# There are 0 directories and 1 images in 'data\626'.
# There are 0 directories and 1 images in 'data\627'.
# There are 0 directories and 1 images in 'data\628'.
# There are 0 directories and 1 images in 'data\629'.
# There are 0 directories and 1 images in 'data\630'.
# There are 0 directories and 1 images in 'data\631'.
# There are 0 directories and 1 images in 'data\632'.
# There are 0 directories and 1 images in 'data\633'.
# There are 0 directories and 9 images in 'data\634'.
# There are 0 directories and 10 images in 'data\635'.
# There are 0 directories and 1 images in 'data\636'.
# There are 0 directories and 1 images in 'data\637'.
# There are 0 directories and 1 images in 'data\638'.
# There are 0 directories and 1 images in 'data\639'.
# There are 0 directories and 1 images in 'data\640'.
# There are 0 directories and 1 images in 'data\641'.
# There are 0 directories and 1 images in 'data\642'.
# There are 0 directories and 1 images in 'data\643'.
# There are 0 directories and 1 images in 'data\644'.
# There are 0 directories and 1 images in 'data\645'.
# There are 0 directories and 1 images in 'data\647'.
# There are 0 directories and 1 images in 'data\648'.
# There are 0 directories and 1 images in 'data\649'.
# There are 0 directories and 1 images in 'data\650'.
# There are 0 directories and 1 images in 'data\651'.
# There are 0 directories and 1 images in 'data\652'.
# There are 0 directories and 1 images in 'data\653'.
# There are 0 directories and 1 images in 'data\654'.
# There are 0 directories and 1 images in 'data\655'.
# There are 0 directories and 2 images in 'data\658'.
# There are 0 directories and 1 images in 'data\659'.
# There are 0 directories and 1 images in 'data\660'.
# There are 0 directories and 1 images in 'data\661'.
# There are 0 directories and 1 images in 'data\662'.
# There are 0 directories and 1 images in 'data\663'.
# There are 0 directories and 1 images in 'data\664'.
# There are 0 directories and 1 images in 'data\665'.
# There are 0 directories and 1 images in 'data\666'.
# There are 0 directories and 1 images in 'data\667'.
# There are 0 directories and 1 images in 'data\668'.
# There are 0 directories and 1 images in 'data\669'.
# There are 0 directories and 10 images in 'data\670'.
# There are 0 directories and 10 images in 'data\671'.

# %%
import os

def walk_through_dir(dir_path):
    texts = []
    for dirpath, dirnames, filenames in os.walk(dir_path):
        num_images = len([f for f in filenames if f.endswith('.png') or f.endswith('.jpg')])
        print(f"There are {len(dirnames)} directories and {num_images} images in '{dirpath}'.")

        # Placeholder for extracting text from each image
        for filename in filenames:
            if filename.endswith('.png') or filename.endswith('.jpg'):
                image_path = os.path.join(dirpath, filename)
                print(f"Found image: {image_path}")
                
                # Simulate OCR output
                extracted_text = f"Text extracted from {filename}"  # Placeholder text
                texts.append(extracted_text)
    
    return texts

# Run directory traversal
texts = walk_through_dir('data')  # Change 'data' to your directory path
print(f"Extracted texts: {texts}")
# Out:
# There are 657 directories and 0 images in 'data'.
# There are 0 directories and 59 images in 'data\000'.
# Found image: data\000\label_10_a01-049u.png
# Found image: data\000\label_11_a01-049x.png
# Found image: data\000\label_12_a01-053u.png
# Found image: data\000\label_13_a01-058u.png
# Found image: data\000\label_14_a01-063u.png
# Found image: data\000\label_15_a01-068u.png
# Found image: data\000\label_16_a01-072u.png
# Found image: data\000\label_17_a01-077u.png
# Found image: data\000\label_18_a01-082u.png
# Found image: data\000\label_19_a01-087u.png
# Found image: data\000\label_1_a01-000u.png
# Found image: data\000\label_20_a01-091u.png
# Found image: data\000\label_21_a01-096u.png
# Found image: data\000\label_22_a01-102u.png
# Found image: data\000\label_23_a01-107u.png
# Found image: data\000\label_24_a01-113u.png
# Found image: data\000\label_25_a01-117u.png
# Found image: data\000\label_26_a01-122u.png
# Found image: data\000\label_27_a01-128u.png
# Found image: data\000\label_28_a01-132u.png
# Found image: data\000\label_29_a01-132x.png
# Found image: data\000\label_2_a01-003u.png
# Found image: data\000\label_30_a03-050.png
# Found image: data\000\label_31_a03-071.png
# Found image: data\000\label_32_a03-073.png
# Found image: data\000\label_33_a03-080.png
# Found image: data\000\label_34_a03-089.png
# Found image: data\000\label_35_a05-000.png
# Found image: data\000\label_36_a05-013.png
# Found image: data\000\label_37_a05-017.png
# Found image: data\000\label_38_a05-022.png
# Found image: data\000\label_39_a05-025.png
# Found image: data\000\label_3_a01-007u.png
# Found image: data\000\label_40_a05-029.png
# Found image: data\000\label_41_a05-039.png
# Found image: data\000\label_42_a05-044.png
# Found image: data\000\label_43_a05-048.png
# Found image: data\000\label_44_a05-053.png
# Found image: data\000\label_45_a05-058.png
# Found image: data\000\label_46_a05-062.png
# Found image: data\000\label_47_a05-069.png
# Found image: data\000\label_48_a05-073.png
# Found image: data\000\label_49_a05-080.png
# Found image: data\000\label_4_a01-011u.png
# Found image: data\000\label_50_a05-084.png
# Found image: data\000\label_51_a05-089.png
# Found image: data\000\label_52_a05-094.png
# Found image: data\000\label_53_a05-099.png
# Found image: data\000\label_54_a05-104.png
# Found image: data\000\label_55_a05-108.png
# Found image: data\000\label_56_a05-113.png
# Found image: data\000\label_57_a05-116.png
# Found image: data\000\label_58_a05-121.png
# Found image: data\000\label_59_a05-125.png
# Found image: data\000\label_5_a01-014u.png
# Found image: data\000\label_6_a01-020u.png
# Found image: data\000\label_7_a01-026u.png
# Found image: data\000\label_8_a01-030u.png
# Found image: data\000\label_9_a01-043u.png
# There are 0 directories and 2 images in 'data\001'.
# Found image: data\001\label_60_a01-000x.png
# Found image: data\001\label_61_a01-072x.png
# There are 0 directories and 1 images in 'data\002'.
# Found image: data\002\label_62_a01-003.png
# There are 0 directories and 2 images in 'data\003'.
# Found image: data\003\label_63_a01-003x.png
# Found image: data\003\label_64_a01-007x.png
# There are 0 directories and 1 images in 'data\004'.
# Found image: data\004\label_65_a01-007.png
# There are 0 directories and 2 images in 'data\005'.
# Found image: data\005\label_66_a01-011.png
# Found image: data\005\label_67_a01-030.png
# There are 0 directories and 1 images in 'data\006'.
# Found image: data\006\label_68_a01-011x.png
# There are 0 directories and 2 images in 'data\007'.
# Found image: data\007\label_69_a01-014.png
# Found image: data\007\label_70_a01-038.png
# There are 0 directories and 2 images in 'data\008'.
# Found image: data\008\label_71_a01-014x.png
# Found image: data\008\label_72_a01-026x.png
# There are 0 directories and 2 images in 'data\009'.
# Found image: data\009\label_73_a01-020.png
# Found image: data\009\label_74_a01-026.png
# There are 0 directories and 2 images in 'data\010'.
# Found image: data\010\label_75_a01-020x.png
# Found image: data\010\label_76_a01-030x.png
# There are 0 directories and 2 images in 'data\011'.
# Found image: data\011\label_77_a01-038x.png
# Found image: data\011\label_78_a01-043x.png
# There are 0 directories and 2 images in 'data\012'.
# Found image: data\012\label_79_a01-043.png
# Found image: data\012\label_80_a01-049.png
# There are 0 directories and 3 images in 'data\013'.
# Found image: data\013\label_81_a01-053.png
# Found image: data\013\label_82_a01-058.png
# Found image: data\013\label_83_a01-063.png
# There are 0 directories and 2 images in 'data\014'.
# Found image: data\014\label_84_a01-053x.png
# Found image: data\014\label_85_a01-058x.png
# There are 0 directories and 1 images in 'data\015'.
# Found image: data\015\label_86_a01-063x.png
# There are 0 directories and 3 images in 'data\016'.
# Found image: data\016\label_87_a01-077.png
# Found image: data\016\label_88_a01-091.png
# Found image: data\016\label_89_a01-102.png
# There are 0 directories and 3 images in 'data\017'.
# Found image: data\017\label_90_a01-087.png
# Found image: data\017\label_91_b01-057.png
# Found image: data\017\label_92_b01-062.png
# There are 0 directories and 2 images in 'data\018'.
# Found image: data\018\label_93_a01-107.png
# Found image: data\018\label_94_a01-113.png
# There are 0 directories and 3 images in 'data\019'.
# Found image: data\019\label_95_a01-117.png
# Found image: data\019\label_96_a01-122.png
# Found image: data\019\label_97_a01-128.png
# There are 0 directories and 1 images in 'data\020'.
# Found image: data\020\label_98_a01-132.png
# There are 0 directories and 1 images in 'data\021'.
# Found image: data\021\label_99_a02-000.png
# There are 0 directories and 1 images in 'data\022'.
# Found image: data\022\label_100_a02-004.png
# There are 0 directories and 1 images in 'data\023'.
# Found image: data\023\label_101_a02-008.png
# There are 0 directories and 1 images in 'data\024'.
# Found image: data\024\label_102_a02-012.png
# There are 0 directories and 5 images in 'data\025'.
# Found image: data\025\label_103_a02-017.png
# Found image: data\025\label_104_a02-020.png
# Found image: data\025\label_105_a02-024.png
# Found image: data\025\label_106_a02-027.png
# Found image: data\025\label_107_a02-032.png
# There are 0 directories and 5 images in 'data\026'.
# Found image: data\026\label_108_a02-037.png
# Found image: data\026\label_109_a02-042.png
# Found image: data\026\label_110_a02-090.png
# Found image: data\026\label_111_a02-093.png
# Found image: data\026\label_112_a02-098.png
# There are 0 directories and 1 images in 'data\027'.
# Found image: data\027\label_113_a02-046.png
# There are 0 directories and 1 images in 'data\028'.
# Found image: data\028\label_114_a02-050.png
# There are 0 directories and 1 images in 'data\029'.
# Found image: data\029\label_115_a02-053.png
# There are 0 directories and 1 images in 'data\030'.
# Found image: data\030\label_116_a02-057.png
# There are 0 directories and 1 images in 'data\031'.
# Found image: data\031\label_117_a02-062.png
# There are 0 directories and 1 images in 'data\032'.
# Found image: data\032\label_118_a02-067.png
# There are 0 directories and 1 images in 'data\033'.
# Found image: data\033\label_119_a02-072.png
# There are 0 directories and 1 images in 'data\034'.
# Found image: data\034\label_120_a02-078.png
# There are 0 directories and 1 images in 'data\035'.
# Found image: data\035\label_121_a02-082.png
# There are 0 directories and 1 images in 'data\036'.
# Found image: data\036\label_122_a02-086.png
# There are 0 directories and 5 images in 'data\037'.
# Found image: data\037\label_123_a02-102.png
# Found image: data\037\label_124_a02-106.png
# Found image: data\037\label_125_a02-111.png
# Found image: data\037\label_126_a02-124.png
# Found image: data\037\label_127_a03-047.png
# There are 0 directories and 1 images in 'data\038'.
# Found image: data\038\label_128_a02-116.png
# There are 0 directories and 1 images in 'data\039'.
# Found image: data\039\label_129_a02-120.png
# There are 0 directories and 1 images in 'data\040'.
# Found image: data\040\label_130_a03-006.png
# There are 0 directories and 1 images in 'data\041'.
# Found image: data\041\label_131_a03-009.png
# There are 0 directories and 1 images in 'data\042'.
# Found image: data\042\label_132_a03-011.png
# There are 0 directories and 1 images in 'data\043'.
# Found image: data\043\label_133_a03-014.png
# There are 0 directories and 1 images in 'data\044'.
# Found image: data\044\label_134_a03-017.png
# There are 0 directories and 1 images in 'data\045'.
# Found image: data\045\label_135_a03-020.png
# There are 0 directories and 1 images in 'data\046'.
# Found image: data\046\label_136_a03-023.png
# There are 0 directories and 1 images in 'data\047'.
# Found image: data\047\label_137_a03-027.png
# There are 0 directories and 1 images in 'data\048'.
# Found image: data\048\label_138_a03-030.png
# There are 0 directories and 1 images in 'data\049'.
# Found image: data\049\label_139_a03-034.png
# There are 0 directories and 1 images in 'data\050'.
# Found image: data\050\label_140_a03-037.png
# There are 0 directories and 1 images in 'data\051'.
# Found image: data\051\label_141_a03-040.png
# There are 0 directories and 1 images in 'data\052'.
# Found image: data\052\label_142_a03-043.png
# There are 0 directories and 1 images in 'data\053'.
# Found image: data\053\label_143_a03-054.png
# There are 0 directories and 1 images in 'data\054'.
# Found image: data\054\label_144_a03-059.png
# There are 0 directories and 1 images in 'data\055'.
# Found image: data\055\label_145_a03-063.png
# There are 0 directories and 1 images in 'data\056'.
# Found image: data\056\label_146_a03-066.png
# There are 0 directories and 4 images in 'data\058'.
# Found image: data\058\label_147_a04-000.png
# Found image: data\058\label_148_a04-003.png
# Found image: data\058\label_149_a04-006.png
# Found image: data\058\label_150_a04-010.png
# There are 0 directories and 4 images in 'data\059'.
# Found image: data\059\label_151_a04-015.png
# Found image: data\059\label_152_a04-019.png
# Found image: data\059\label_153_a04-023.png
# Found image: data\059\label_154_a04-027.png
# There are 0 directories and 4 images in 'data\060'.
# Found image: data\060\label_155_a04-031.png
# Found image: data\060\label_156_a04-035.png
# Found image: data\060\label_157_a04-039.png
# Found image: data\060\label_158_a04-043.png
# There are 0 directories and 4 images in 'data\061'.
# Found image: data\061\label_159_a04-047.png
# Found image: data\061\label_160_a04-050.png
# Found image: data\061\label_161_a04-054.png
# Found image: data\061\label_162_a04-059.png
# There are 0 directories and 3 images in 'data\062'.
# Found image: data\062\label_163_a04-066.png
# Found image: data\062\label_164_a04-069.png
# Found image: data\062\label_165_a04-072.png
# There are 0 directories and 3 images in 'data\063'.
# Found image: data\063\label_166_a04-081.png
# Found image: data\063\label_167_a04-085.png
# Found image: data\063\label_168_a04-089.png
# There are 0 directories and 4 images in 'data\064'.
# Found image: data\064\label_169_a04-092.png
# Found image: data\064\label_170_a04-096.png
# Found image: data\064\label_171_a04-099.png
# Found image: data\064\label_172_a04-103.png
# There are 0 directories and 2 images in 'data\065'.
# Found image: data\065\label_173_a05-004.png
# Found image: data\065\label_174_a05-009.png
# There are 0 directories and 2 images in 'data\066'.
# Found image: data\066\label_175_a06-000.png
# Found image: data\066\label_176_a06-004.png
# There are 0 directories and 1 images in 'data\067'.
# Found image: data\067\label_177_a06-008.png
# There are 0 directories and 1 images in 'data\068'.
# Found image: data\068\label_178_a06-014.png
# There are 0 directories and 1 images in 'data\069'.
# Found image: data\069\label_179_a06-020.png
# There are 0 directories and 1 images in 'data\070'.
# Found image: data\070\label_180_a06-025.png
# There are 0 directories and 1 images in 'data\071'.
# Found image: data\071\label_181_a06-036.png
# There are 0 directories and 1 images in 'data\072'.
# Found image: data\072\label_182_a06-039.png
# There are 0 directories and 1 images in 'data\073'.
# Found image: data\073\label_183_a06-044.png
# There are 0 directories and 1 images in 'data\074'.
# Found image: data\074\label_184_a06-051.png
# There are 0 directories and 1 images in 'data\075'.
# Found image: data\075\label_185_a06-057.png
# There are 0 directories and 1 images in 'data\076'.
# Found image: data\076\label_186_a06-064.png
# There are 0 directories and 1 images in 'data\077'.
# Found image: data\077\label_187_a06-070.png
# There are 0 directories and 1 images in 'data\078'.
# Found image: data\078\label_188_a06-075.png
# There are 0 directories and 1 images in 'data\079'.
# Found image: data\079\label_189_a06-090.png
# There are 0 directories and 1 images in 'data\080'.
# Found image: data\080\label_190_a06-095.png
# There are 0 directories and 2 images in 'data\081'.
# Found image: data\081\label_191_a06-100.png
# Found image: data\081\label_192_n02-146.png
# There are 0 directories and 1 images in 'data\082'.
# Found image: data\082\label_193_a06-110.png
# There are 0 directories and 1 images in 'data\083'.
# Found image: data\083\label_194_a06-114.png
# There are 0 directories and 2 images in 'data\084'.
# Found image: data\084\label_195_a06-119.png
# Found image: data\084\label_196_a06-128.png
# There are 0 directories and 6 images in 'data\085'.
# Found image: data\085\label_197_a06-124.png
# Found image: data\085\label_198_a06-134.png
# Found image: data\085\label_199_a06-141.png
# Found image: data\085\label_200_a06-147.png
# Found image: data\085\label_201_a06-157.png
# Found image: data\085\label_202_e07-000.png
# There are 0 directories and 1 images in 'data\086'.
# Found image: data\086\label_203_a06-152.png
# There are 0 directories and 3 images in 'data\087'.
# Found image: data\087\label_204_b01-000.png
# Found image: data\087\label_205_b01-004.png
# Found image: data\087\label_206_b01-009.png
# There are 0 directories and 3 images in 'data\088'.
# Found image: data\088\label_207_b01-014.png
# Found image: data\088\label_208_b01-018.png
# Found image: data\088\label_209_b01-023.png
# There are 0 directories and 3 images in 'data\089'.
# Found image: data\089\label_210_b01-027.png
# Found image: data\089\label_211_b01-033.png
# Found image: data\089\label_212_b01-038.png
# There are 0 directories and 3 images in 'data\090'.
# Found image: data\090\label_213_b01-044.png
# Found image: data\090\label_214_b01-049.png
# Found image: data\090\label_215_b01-053.png
# There are 0 directories and 2 images in 'data\091'.
# Found image: data\091\label_216_b01-073.png
# Found image: data\091\label_217_b01-079.png
# There are 0 directories and 3 images in 'data\092'.
# Found image: data\092\label_218_b01-084.png
# Found image: data\092\label_219_b01-089.png
# Found image: data\092\label_220_b01-094.png
# There are 0 directories and 3 images in 'data\093'.
# Found image: data\093\label_221_b01-113.png
# Found image: data\093\label_222_b01-118.png
# Found image: data\093\label_223_b01-122.png
# There are 0 directories and 3 images in 'data\094'.
# Found image: data\094\label_224_b01-127.png
# Found image: data\094\label_225_b01-132.png
# Found image: data\094\label_226_b01-136.png
# There are 0 directories and 2 images in 'data\095'.
# Found image: data\095\label_227_b02-013.png
# Found image: data\095\label_228_b02-035.png
# There are 0 directories and 1 images in 'data\096'.
# Found image: data\096\label_229_b02-045.png
# There are 0 directories and 1 images in 'data\097'.
# Found image: data\097\label_230_b02-097.png
# There are 0 directories and 1 images in 'data\098'.
# Found image: data\098\label_231_b02-102.png
# There are 0 directories and 1 images in 'data\099'.
# Found image: data\099\label_232_b02-105.png
# There are 0 directories and 1 images in 'data\100'.
# Found image: data\100\label_233_b03-025.png
# There are 0 directories and 2 images in 'data\102'.
# Found image: data\102\label_234_b03-087.png
# Found image: data\102\label_235_b03-092.png
# There are 0 directories and 1 images in 'data\103'.
# Found image: data\103\label_236_b03-098.png
# There are 0 directories and 1 images in 'data\104'.
# Found image: data\104\label_237_b03-104.png
# There are 0 directories and 1 images in 'data\105'.
# Found image: data\105\label_238_b03-109.png
# There are 0 directories and 1 images in 'data\106'.
# Found image: data\106\label_239_b03-114.png
# There are 0 directories and 4 images in 'data\107'.
# Found image: data\107\label_240_b04-000.png
# Found image: data\107\label_241_b04-004.png
# Found image: data\107\label_242_b04-010.png
# Found image: data\107\label_243_b04-020.png
# There are 0 directories and 4 images in 'data\108'.
# Found image: data\108\label_244_b04-026.png
# Found image: data\108\label_245_b04-034.png
# Found image: data\108\label_246_b04-040.png
# Found image: data\108\label_247_b04-047.png
# There are 0 directories and 4 images in 'data\109'.
# Found image: data\109\label_248_b04-054.png
# Found image: data\109\label_249_b04-060.png
# Found image: data\109\label_250_b04-066.png
# Found image: data\109\label_251_b04-075.png
# There are 0 directories and 4 images in 'data\110'.
# Found image: data\110\label_252_b04-081.png
# Found image: data\110\label_253_b04-089.png
# Found image: data\110\label_254_b04-096.png
# Found image: data\110\label_255_b04-103.png
# There are 0 directories and 4 images in 'data\111'.
# Found image: data\111\label_256_b04-107.png
# Found image: data\111\label_257_b04-116.png
# Found image: data\111\label_258_b04-121.png
# Found image: data\111\label_259_b04-128.png
# There are 0 directories and 4 images in 'data\112'.
# Found image: data\112\label_260_b04-134.png
# Found image: data\112\label_261_b04-140.png
# Found image: data\112\label_262_b04-147.png
# Found image: data\112\label_263_b04-154.png
# There are 0 directories and 4 images in 'data\113'.
# Found image: data\113\label_264_b04-162.png
# Found image: data\113\label_265_b04-169.png
# Found image: data\113\label_266_b04-175.png
# Found image: data\113\label_267_b04-181.png
# There are 0 directories and 4 images in 'data\114'.
# Found image: data\114\label_268_b04-187.png
# Found image: data\114\label_269_b04-195.png
# Found image: data\114\label_270_b04-202.png
# Found image: data\114\label_271_b04-208.png
# There are 0 directories and 1 images in 'data\115'.
# Found image: data\115\label_272_b05-017.png
# There are 0 directories and 1 images in 'data\116'.
# Found image: data\116\label_273_b05-032.png
# There are 0 directories and 4 images in 'data\117'.
# Found image: data\117\label_274_b05-038.png
# Found image: data\117\label_275_b05-042.png
# Found image: data\117\label_276_b05-045.png
# Found image: data\117\label_277_b05-050.png
# There are 0 directories and 7 images in 'data\118'.
# Found image: data\118\label_278_b05-055.png
# Found image: data\118\label_279_b05-058.png
# Found image: data\118\label_280_b05-062.png
# Found image: data\118\label_281_b05-067.png
# Found image: data\118\label_282_b05-071.png
# Found image: data\118\label_283_g05-098.png
# Found image: data\118\label_284_h05-012.png
# There are 0 directories and 2 images in 'data\119'.
# Found image: data\119\label_285_b05-074.png
# Found image: data\119\label_286_g05-094.png
# There are 0 directories and 1 images in 'data\120'.
# Found image: data\120\label_287_b05-079.png
# There are 0 directories and 2 images in 'data\121'.
# Found image: data\121\label_288_b05-083.png
# Found image: data\121\label_289_b05-098.png
# There are 0 directories and 1 images in 'data\122'.
# Found image: data\122\label_290_b05-088.png
# There are 0 directories and 5 images in 'data\123'.
# Found image: data\123\label_291_b06-000.png
# Found image: data\123\label_292_b06-023.png
# Found image: data\123\label_293_b06-097.png
# Found image: data\123\label_294_c06-039.png
# Found image: data\123\label_295_c06-100.png
# There are 0 directories and 4 images in 'data\124'.
# Found image: data\124\label_296_b06-004.png
# Found image: data\124\label_297_b06-049.png
# Found image: data\124\label_298_b06-075.png
# Found image: data\124\label_299_c06-111.png
# There are 0 directories and 5 images in 'data\125'.
# Found image: data\125\label_300_b06-008.png
# Found image: data\125\label_301_b06-056.png
# Found image: data\125\label_302_b06-093.png
# Found image: data\125\label_303_c06-005.png
# Found image: data\125\label_304_c06-020.png
# There are 0 directories and 5 images in 'data\126'.
# Found image: data\126\label_305_b06-012.png
# Found image: data\126\label_306_b06-036.png
# Found image: data\126\label_307_b06-110.png
# Found image: data\126\label_308_c06-052.png
# Found image: data\126\label_309_c06-087.png
# There are 0 directories and 3 images in 'data\127'.
# Found image: data\127\label_310_b06-015.png
# Found image: data\127\label_311_b06-053.png
# Found image: data\127\label_312_c06-106.png
# There are 0 directories and 5 images in 'data\128'.
# Found image: data\128\label_313_b06-019.png
# Found image: data\128\label_314_b06-071.png
# Found image: data\128\label_315_c06-027.png
# Found image: data\128\label_316_c06-076.png
# Found image: data\128\label_317_c06-128.png
# There are 0 directories and 4 images in 'data\129'.
# Found image: data\129\label_318_b06-027.png
# Found image: data\129\label_319_c06-014.png
# Found image: data\129\label_320_c06-103.png
# Found image: data\129\label_321_c06-138.png
# There are 0 directories and 5 images in 'data\130'.
# Found image: data\130\label_322_b06-032.png
# Found image: data\130\label_323_b06-059.png
# Found image: data\130\label_324_b06-079.png
# Found image: data\130\label_325_c06-000.png
# Found image: data\130\label_326_c06-031.png
# There are 0 directories and 4 images in 'data\131'.
# Found image: data\131\label_327_b06-042.png
# Found image: data\131\label_328_b06-068.png
# Found image: data\131\label_329_c06-058.png
# Found image: data\131\label_330_c06-095.png
# There are 0 directories and 4 images in 'data\132'.
# Found image: data\132\label_331_b06-045.png
# Found image: data\132\label_332_b06-082.png
# Found image: data\132\label_333_c06-047.png
# Found image: data\132\label_334_c06-091.png
# There are 0 directories and 5 images in 'data\133'.
# Found image: data\133\label_335_b06-064.png
# Found image: data\133\label_336_b06-100.png
# Found image: data\133\label_337_c06-043.png
# Found image: data\133\label_338_c06-080.png
# Found image: data\133\label_339_c06-116.png
# There are 0 directories and 2 images in 'data\134'.
# Found image: data\134\label_340_b06-087.png
# Found image: data\134\label_341_b06-090.png
# There are 0 directories and 2 images in 'data\135'.
# Found image: data\135\label_342_c01-009.png
# Found image: data\135\label_343_c01-014.png
# There are 0 directories and 1 images in 'data\136'.
# Found image: data\136\label_344_c01-066.png
# There are 0 directories and 1 images in 'data\137'.
# Found image: data\137\label_345_c02-000.png
# There are 0 directories and 1 images in 'data\138'.
# Found image: data\138\label_346_c02-003.png
# There are 0 directories and 2 images in 'data\139'.
# Found image: data\139\label_347_c02-007.png
# Found image: data\139\label_348_c02-017.png
# There are 0 directories and 2 images in 'data\140'.
# Found image: data\140\label_349_c02-012.png
# Found image: data\140\label_350_c02-022.png
# There are 0 directories and 1 images in 'data\141'.
# Found image: data\141\label_351_c02-026.png
# There are 0 directories and 1 images in 'data\142'.
# Found image: data\142\label_352_c02-030.png
# There are 0 directories and 1 images in 'data\143'.
# Found image: data\143\label_353_c02-035.png
# There are 0 directories and 1 images in 'data\144'.
# Found image: data\144\label_354_c02-049.png
# There are 0 directories and 1 images in 'data\145'.
# Found image: data\145\label_355_c02-056.png
# There are 0 directories and 1 images in 'data\146'.
# Found image: data\146\label_356_c02-059.png
# There are 0 directories and 1 images in 'data\147'.
# Found image: data\147\label_357_c02-078.png
# There are 0 directories and 1 images in 'data\148'.
# Found image: data\148\label_358_c02-082.png
# There are 0 directories and 1 images in 'data\149'.
# Found image: data\149\label_359_c02-089.png
# There are 0 directories and 10 images in 'data\150'.
# Found image: data\150\label_360_c03-000a.png
# Found image: data\150\label_361_c03-003a.png
# Found image: data\150\label_362_c03-007a.png
# Found image: data\150\label_363_c03-016a.png
# Found image: data\150\label_364_c03-021a.png
# Found image: data\150\label_365_c03-081a.png
# Found image: data\150\label_366_c03-084a.png
# Found image: data\150\label_367_c03-087a.png
# Found image: data\150\label_368_c03-094a.png
# Found image: data\150\label_369_c03-096a.png
# There are 0 directories and 10 images in 'data\151'.
# Found image: data\151\label_370_c03-000b.png
# Found image: data\151\label_371_c03-003b.png
# Found image: data\151\label_372_c03-007b.png
# Found image: data\151\label_373_c03-016b.png
# Found image: data\151\label_374_c03-021b.png
# Found image: data\151\label_375_c03-081b.png
# Found image: data\151\label_376_c03-084b.png
# Found image: data\151\label_377_c03-087b.png
# Found image: data\151\label_378_c03-094b.png
# Found image: data\151\label_379_c03-096b.png
# There are 0 directories and 10 images in 'data\152'.
# Found image: data\152\label_380_c03-000c.png
# Found image: data\152\label_381_c03-003c.png
# Found image: data\152\label_382_c03-007c.png
# Found image: data\152\label_383_c03-016c.png
# Found image: data\152\label_384_c03-021c.png
# Found image: data\152\label_385_c03-081c.png
# Found image: data\152\label_386_c03-084c.png
# Found image: data\152\label_387_c03-087c.png
# Found image: data\152\label_388_c03-094c.png
# Found image: data\152\label_389_c03-096c.png
# There are 0 directories and 10 images in 'data\153'.
# Found image: data\153\label_390_c03-000d.png
# Found image: data\153\label_391_c03-003d.png
# Found image: data\153\label_392_c03-007d.png
# Found image: data\153\label_393_c03-016d.png
# Found image: data\153\label_394_c03-021d.png
# Found image: data\153\label_395_c03-081d.png
# Found image: data\153\label_396_c03-084d.png
# Found image: data\153\label_397_c03-087d.png
# Found image: data\153\label_398_c03-094d.png
# Found image: data\153\label_399_c03-096d.png
# There are 0 directories and 10 images in 'data\154'.
# Found image: data\154\label_400_c03-000e.png
# Found image: data\154\label_401_c03-003e.png
# Found image: data\154\label_402_c03-007e.png
# Found image: data\154\label_403_c03-016e.png
# Found image: data\154\label_404_c03-021e.png
# Found image: data\154\label_405_c03-081e.png
# Found image: data\154\label_406_c03-084e.png
# Found image: data\154\label_407_c03-087e.png
# Found image: data\154\label_408_c03-094e.png
# Found image: data\154\label_409_c03-096e.png
# There are 0 directories and 9 images in 'data\155'.
# Found image: data\155\label_410_c03-000f.png
# Found image: data\155\label_411_c03-003f.png
# Found image: data\155\label_412_c03-007f.png
# Found image: data\155\label_413_c03-021f.png
# Found image: data\155\label_414_c03-081f.png
# Found image: data\155\label_415_c03-084f.png
# Found image: data\155\label_416_c03-087f.png
# Found image: data\155\label_417_c03-094f.png
# Found image: data\155\label_418_c03-096f.png
# There are 0 directories and 1 images in 'data\156'.
# Found image: data\156\label_419_c03-007.png
# There are 0 directories and 2 images in 'data\157'.
# Found image: data\157\label_420_c04-000.png
# Found image: data\157\label_421_c04-004.png
# There are 0 directories and 3 images in 'data\158'.
# Found image: data\158\label_422_c04-008.png
# Found image: data\158\label_423_c04-013.png
# Found image: data\158\label_424_e04-000.png
# There are 0 directories and 2 images in 'data\159'.
# Found image: data\159\label_425_c04-017.png
# Found image: data\159\label_426_c04-035.png
# There are 0 directories and 2 images in 'data\160'.
# Found image: data\160\label_427_c04-023.png
# Found image: data\160\label_428_c04-028.png
# There are 0 directories and 2 images in 'data\161'.
# Found image: data\161\label_429_c04-039.png
# Found image: data\161\label_430_c04-044.png
# There are 0 directories and 2 images in 'data\162'.
# Found image: data\162\label_431_c04-050.png
# Found image: data\162\label_432_c04-056.png
# There are 0 directories and 2 images in 'data\163'.
# Found image: data\163\label_433_c04-061.png
# Found image: data\163\label_434_c04-066.png
# There are 0 directories and 2 images in 'data\164'.
# Found image: data\164\label_435_c04-075.png
# Found image: data\164\label_436_c04-122.png
# There are 0 directories and 2 images in 'data\165'.
# Found image: data\165\label_437_c04-080.png
# Found image: data\165\label_438_c04-128.png
# There are 0 directories and 2 images in 'data\166'.
# Found image: data\166\label_439_c04-089.png
# Found image: data\166\label_440_c04-098.png
# There are 0 directories and 1 images in 'data\167'.
# Found image: data\167\label_441_c04-105.png
# There are 0 directories and 2 images in 'data\168'.
# Found image: data\168\label_442_c04-110.png
# Found image: data\168\label_443_c04-116.png
# There are 0 directories and 2 images in 'data\169'.
# Found image: data\169\label_444_c04-134.png
# Found image: data\169\label_445_c04-139.png
# There are 0 directories and 2 images in 'data\170'.
# Found image: data\170\label_446_c04-144.png
# Found image: data\170\label_447_c04-150.png
# There are 0 directories and 2 images in 'data\171'.
# Found image: data\171\label_448_c04-156.png
# Found image: data\171\label_449_c04-160.png
# There are 0 directories and 2 images in 'data\172'.
# Found image: data\172\label_450_c04-165.png
# Found image: data\172\label_451_c04-170.png
# There are 0 directories and 5 images in 'data\173'.
# Found image: data\173\label_452_c06-011.png
# Found image: data\173\label_453_d06-008.png
# Found image: data\173\label_454_d06-020.png
# Found image: data\173\label_455_d06-046.png
# Found image: data\173\label_456_d06-063.png
# There are 0 directories and 5 images in 'data\174'.
# Found image: data\174\label_457_c06-083.png
# Found image: data\174\label_458_d06-015.png
# Found image: data\174\label_459_d06-030.png
# Found image: data\174\label_460_d06-050.png
# Found image: data\174\label_461_d06-082.png
# There are 0 directories and 2 images in 'data\175'.
# Found image: data\175\label_462_d01-016.png
# Found image: data\175\label_463_d01-019.png
# There are 0 directories and 1 images in 'data\176'.
# Found image: data\176\label_464_d01-024.png
# There are 0 directories and 2 images in 'data\177'.
# Found image: data\177\label_465_d01-049.png
# Found image: data\177\label_466_d01-052.png
# There are 0 directories and 2 images in 'data\178'.
# Found image: data\178\label_467_d01-056.png
# Found image: data\178\label_468_d01-060.png
# There are 0 directories and 2 images in 'data\179'.
# Found image: data\179\label_469_d01-080.png
# Found image: data\179\label_470_d01-085.png
# There are 0 directories and 2 images in 'data\180'.
# Found image: data\180\label_471_d01-098.png
# Found image: data\180\label_472_d01-104.png
# There are 0 directories and 3 images in 'data\181'.
# Found image: data\181\label_473_d01-118.png
# Found image: data\181\label_474_d01-123.png
# Found image: data\181\label_475_e01-055.png
# There are 0 directories and 1 images in 'data\182'.
# Found image: data\182\label_476_d03-112.png
# There are 0 directories and 1 images in 'data\183'.
# Found image: data\183\label_477_d03-117.png
# There are 0 directories and 2 images in 'data\184'.
# Found image: data\184\label_478_d04-005.png
# Found image: data\184\label_479_d04-008.png
# There are 0 directories and 2 images in 'data\185'.
# Found image: data\185\label_480_d04-012.png
# Found image: data\185\label_481_d04-016.png
# There are 0 directories and 2 images in 'data\186'.
# Found image: data\186\label_482_d04-021.png
# Found image: data\186\label_483_d04-028.png
# There are 0 directories and 2 images in 'data\187'.
# Found image: data\187\label_484_d04-032.png
# Found image: data\187\label_485_d04-037.png
# There are 0 directories and 2 images in 'data\188'.
# Found image: data\188\label_486_d04-047.png
# Found image: data\188\label_487_d04-053.png
# There are 0 directories and 1 images in 'data\189'.
# Found image: data\189\label_488_d04-050.png
# There are 0 directories and 2 images in 'data\190'.
# Found image: data\190\label_489_d04-058.png
# Found image: data\190\label_490_d04-062.png
# There are 0 directories and 1 images in 'data\191'.
# Found image: data\191\label_491_d04-066.png
# There are 0 directories and 2 images in 'data\192'.
# Found image: data\192\label_492_d04-071.png
# Found image: data\192\label_493_d04-075.png
# There are 0 directories and 4 images in 'data\193'.
# Found image: data\193\label_494_d04-081.png
# Found image: data\193\label_495_f04-093.png
# Found image: data\193\label_496_f04-096.png
# Found image: data\193\label_497_f04-100.png
# There are 0 directories and 2 images in 'data\194'.
# Found image: data\194\label_498_d04-086.png
# Found image: data\194\label_499_d04-089.png
# There are 0 directories and 2 images in 'data\195'.
# Found image: data\195\label_500_d04-096.png
# Found image: data\195\label_501_d04-101.png
# There are 0 directories and 1 images in 'data\196'.
# Found image: data\196\label_502_d04-111.png
# There are 0 directories and 2 images in 'data\197'.
# Found image: data\197\label_503_d04-117.png
# Found image: data\197\label_504_d04-121.png
# There are 0 directories and 2 images in 'data\198'.
# Found image: data\198\label_505_d04-125.png
# Found image: data\198\label_506_d04-131.png
# There are 0 directories and 4 images in 'data\199'.
# Found image: data\199\label_507_d05-008.png
# Found image: data\199\label_508_d05-021.png
# Found image: data\199\label_509_d05-025.png
# Found image: data\199\label_510_d05-030.png
# There are 0 directories and 1 images in 'data\200'.
# Found image: data\200\label_511_d05-013.png
# There are 0 directories and 1 images in 'data\201'.
# Found image: data\201\label_512_d05-040.png
# There are 0 directories and 5 images in 'data\202'.
# Found image: data\202\label_513_d06-000.png
# Found image: data\202\label_514_d06-091.png
# Found image: data\202\label_515_e06-006.png
# Found image: data\202\label_516_e06-037.png
# Found image: data\202\label_517_e06-041.png
# There are 0 directories and 5 images in 'data\203'.
# Found image: data\203\label_518_d06-003.png
# Found image: data\203\label_519_d06-076.png
# Found image: data\203\label_520_d06-111.png
# Found image: data\203\label_521_e06-010.png
# Found image: data\203\label_522_e06-046.png
# There are 0 directories and 5 images in 'data\204'.
# Found image: data\204\label_523_d06-011.png
# Found image: data\204\label_524_d06-107.png
# Found image: data\204\label_525_e06-003.png
# Found image: data\204\label_526_e06-015.png
# Found image: data\204\label_527_e06-030.png
# There are 0 directories and 5 images in 'data\205'.
# Found image: data\205\label_528_d06-025.png
# Found image: data\205\label_529_d06-067.png
# Found image: data\205\label_530_d06-104.png
# Found image: data\205\label_531_e06-026.png
# Found image: data\205\label_532_e06-049.png
# There are 0 directories and 5 images in 'data\206'.
# Found image: data\206\label_533_d06-027.png
# Found image: data\206\label_534_d06-056.png
# Found image: data\206\label_535_d06-096.png
# Found image: data\206\label_536_e06-000.png
# Found image: data\206\label_537_e06-021.png
# There are 0 directories and 5 images in 'data\207'.
# Found image: data\207\label_538_d06-037.png
# Found image: data\207\label_539_d06-072.png
# Found image: data\207\label_540_d06-100.png
# Found image: data\207\label_541_e06-033.png
# Found image: data\207\label_542_e06-070.png
# There are 0 directories and 5 images in 'data\208'.
# Found image: data\208\label_543_d06-041.png
# Found image: data\208\label_544_d06-060.png
# Found image: data\208\label_545_d06-086.png
# Found image: data\208\label_546_d06-113.png
# Found image: data\208\label_547_e06-053.png
# There are 0 directories and 7 images in 'data\209'.
# Found image: data\209\label_548_d07-082.png
# Found image: data\209\label_549_d07-085.png
# Found image: data\209\label_550_d07-089.png
# Found image: data\209\label_551_d07-093.png
# Found image: data\209\label_552_d07-096.png
# Found image: data\209\label_553_d07-100.png
# Found image: data\209\label_554_d07-102.png
# There are 0 directories and 2 images in 'data\210'.
# Found image: data\210\label_555_e01-014.png
# Found image: data\210\label_556_e01-018.png
# There are 0 directories and 2 images in 'data\211'.
# Found image: data\211\label_557_e01-022.png
# Found image: data\211\label_558_e01-025.png
# There are 0 directories and 3 images in 'data\212'.
# Found image: data\212\label_559_e01-029.png
# Found image: data\212\label_560_e01-032.png
# Found image: data\212\label_561_e01-035.png
# There are 0 directories and 3 images in 'data\213'.
# Found image: data\213\label_562_e01-050.png
# Found image: data\213\label_563_e01-059.png
# Found image: data\213\label_564_e01-062.png
# There are 0 directories and 2 images in 'data\214'.
# Found image: data\214\label_565_e01-081.png
# Found image: data\214\label_566_e01-086.png
# There are 0 directories and 2 images in 'data\215'.
# Found image: data\215\label_567_e01-092.png
# Found image: data\215\label_568_e01-102.png
# There are 0 directories and 2 images in 'data\216'.
# Found image: data\216\label_569_e01-107.png
# Found image: data\216\label_570_e01-113.png
# There are 0 directories and 3 images in 'data\217'.
# Found image: data\217\label_571_e01-119.png
# Found image: data\217\label_572_f01-139.png
# Found image: data\217\label_573_g01-000.png
# There are 0 directories and 1 images in 'data\218'.
# Found image: data\218\label_574_e02-000.png
# There are 0 directories and 1 images in 'data\219'.
# Found image: data\219\label_575_e02-014.png
# There are 0 directories and 1 images in 'data\220'.
# Found image: data\220\label_576_e02-018.png
# There are 0 directories and 1 images in 'data\221'.
# Found image: data\221\label_577_e02-021.png
# There are 0 directories and 1 images in 'data\222'.
# Found image: data\222\label_578_e02-025.png
# There are 0 directories and 1 images in 'data\223'.
# Found image: data\223\label_579_e02-074.png
# There are 0 directories and 1 images in 'data\224'.
# Found image: data\224\label_580_e02-082.png
# There are 0 directories and 1 images in 'data\225'.
# Found image: data\225\label_581_e02-086.png
# There are 0 directories and 1 images in 'data\226'.
# Found image: data\226\label_582_e02-091.png
# There are 0 directories and 1 images in 'data\227'.
# Found image: data\227\label_583_e02-094.png
# There are 0 directories and 1 images in 'data\228'.
# Found image: data\228\label_584_e02-100.png
# There are 0 directories and 1 images in 'data\229'.
# Found image: data\229\label_585_e02-117.png
# There are 0 directories and 2 images in 'data\230'.
# Found image: data\230\label_586_e04-004.png
# Found image: data\230\label_587_e04-008.png
# There are 0 directories and 2 images in 'data\231'.
# Found image: data\231\label_588_e04-011.png
# Found image: data\231\label_589_e04-015.png
# There are 0 directories and 2 images in 'data\232'.
# Found image: data\232\label_590_e04-019.png
# Found image: data\232\label_591_e04-022.png
# There are 0 directories and 2 images in 'data\233'.
# Found image: data\233\label_592_e04-026.png
# Found image: data\233\label_593_e04-030.png
# There are 0 directories and 2 images in 'data\234'.
# Found image: data\234\label_594_e04-034.png
# Found image: data\234\label_595_e04-038.png
# There are 0 directories and 2 images in 'data\235'.
# Found image: data\235\label_596_e04-043.png
# Found image: data\235\label_597_e04-052.png
# There are 0 directories and 1 images in 'data\236'.
# Found image: data\236\label_598_e04-058.png
# There are 0 directories and 2 images in 'data\237'.
# Found image: data\237\label_599_e04-062.png
# Found image: data\237\label_600_e04-068.png
# There are 0 directories and 1 images in 'data\238'.
# Found image: data\238\label_601_e04-079.png
# There are 0 directories and 4 images in 'data\239'.
# Found image: data\239\label_602_e04-083.png
# Found image: data\239\label_603_g04-003.png
# Found image: data\239\label_604_h04-000.png
# Found image: data\239\label_605_k04-017.png
# There are 0 directories and 2 images in 'data\240'.
# Found image: data\240\label_606_e04-086.png
# Found image: data\240\label_607_k04-022.png
# There are 0 directories and 4 images in 'data\241'.
# Found image: data\241\label_608_e04-091.png
# Found image: data\241\label_609_e04-095.png
# Found image: data\241\label_610_e04-099.png
# Found image: data\241\label_611_e04-132.png
# There are 0 directories and 3 images in 'data\242'.
# Found image: data\242\label_612_e04-103.png
# Found image: data\242\label_613_e04-109.png
# Found image: data\242\label_614_e04-114.png
# There are 0 directories and 3 images in 'data\243'.
# Found image: data\243\label_615_e04-119.png
# Found image: data\243\label_616_e04-124.png
# Found image: data\243\label_617_e04-127.png
# There are 0 directories and 1 images in 'data\244'.
# Found image: data\244\label_618_e07-003.png
# There are 0 directories and 1 images in 'data\245'.
# Found image: data\245\label_619_e07-007.png
# There are 0 directories and 4 images in 'data\246'.
# Found image: data\246\label_620_e07-012.png
# Found image: data\246\label_621_e07-061.png
# Found image: data\246\label_622_e07-066.png
# Found image: data\246\label_623_e07-072.png
# There are 0 directories and 5 images in 'data\247'.
# Found image: data\247\label_624_e07-076.png
# Found image: data\247\label_625_e07-079.png
# Found image: data\247\label_626_e07-083.png
# Found image: data\247\label_627_e07-086.png
# Found image: data\247\label_628_e07-090.png
# There are 0 directories and 5 images in 'data\248'.
# Found image: data\248\label_629_e07-094.png
# Found image: data\248\label_630_e07-098.png
# Found image: data\248\label_631_e07-101.png
# Found image: data\248\label_632_e07-105.png
# Found image: data\248\label_633_e07-108.png
# There are 0 directories and 1 images in 'data\249'.
# Found image: data\249\label_634_e07-112.png
# There are 0 directories and 2 images in 'data\250'.
# Found image: data\250\label_635_f01-053.png
# Found image: data\250\label_636_f01-058.png
# There are 0 directories and 1 images in 'data\251'.
# Found image: data\251\label_637_f01-066.png
# There are 0 directories and 1 images in 'data\252'.
# Found image: data\252\label_638_f01-070.png
# There are 0 directories and 1 images in 'data\253'.
# Found image: data\253\label_639_f01-075.png
# There are 0 directories and 2 images in 'data\254'.
# Found image: data\254\label_640_f01-081.png
# Found image: data\254\label_641_f01-085.png
# There are 0 directories and 1 images in 'data\255'.
# Found image: data\255\label_642_f01-135.png
# There are 0 directories and 2 images in 'data\256'.
# Found image: data\256\label_643_f01-143.png
# Found image: data\256\label_644_f01-147.png
# There are 0 directories and 1 images in 'data\257'.
# Found image: data\257\label_645_f02-000.png
# There are 0 directories and 1 images in 'data\258'.
# Found image: data\258\label_646_f02-003.png
# There are 0 directories and 2 images in 'data\259'.
# Found image: data\259\label_647_f02-017.png
# Found image: data\259\label_648_f02-033.png
# There are 0 directories and 1 images in 'data\260'.
# Found image: data\260\label_649_f02-020.png
# There are 0 directories and 1 images in 'data\261'.
# Found image: data\261\label_650_f02-030.png
# There are 0 directories and 1 images in 'data\262'.
# Found image: data\262\label_651_f02-036.png
# There are 0 directories and 1 images in 'data\263'.
# Found image: data\263\label_652_f02-038.png
# There are 0 directories and 1 images in 'data\264'.
# Found image: data\264\label_653_f02-040.png
# There are 0 directories and 1 images in 'data\265'.
# Found image: data\265\label_654_f02-044.png
# There are 0 directories and 1 images in 'data\266'.
# Found image: data\266\label_655_f02-076.png
# There are 0 directories and 1 images in 'data\267'.
# Found image: data\267\label_656_f03-169.png
# There are 0 directories and 1 images in 'data\268'.
# Found image: data\268\label_657_f03-174.png
# There are 0 directories and 1 images in 'data\269'.
# Found image: data\269\label_658_f03-182.png
# There are 0 directories and 1 images in 'data\270'.
# Found image: data\270\label_659_f03-191.png
# There are 0 directories and 3 images in 'data\272'.
# Found image: data\272\label_660_f04-004.png
# Found image: data\272\label_661_f04-011.png
# Found image: data\272\label_662_f04-016.png
# There are 0 directories and 5 images in 'data\273'.
# Found image: data\273\label_663_f04-007.png
# Found image: data\273\label_664_g04-007.png
# Found image: data\273\label_665_g04-011.png
# Found image: data\273\label_666_g04-014.png
# Found image: data\273\label_667_g04-095.png
# There are 0 directories and 5 images in 'data\274'.
# Found image: data\274\label_668_f04-020.png
# Found image: data\274\label_669_g04-017.png
# Found image: data\274\label_670_g04-026.png
# Found image: data\274\label_671_g04-032.png
# Found image: data\274\label_672_h04-025.png
# There are 0 directories and 2 images in 'data\275'.
# Found image: data\275\label_673_f04-024.png
# Found image: data\275\label_674_f04-028.png
# There are 0 directories and 2 images in 'data\276'.
# Found image: data\276\label_675_f04-032.png
# Found image: data\276\label_676_f04-035.png
# There are 0 directories and 2 images in 'data\277'.
# Found image: data\277\label_677_f04-039.png
# Found image: data\277\label_678_f04-043.png
# There are 0 directories and 2 images in 'data\278'.
# Found image: data\278\label_679_f04-046.png
# Found image: data\278\label_680_f04-049.png
# There are 0 directories and 2 images in 'data\279'.
# Found image: data\279\label_681_f04-053.png
# Found image: data\279\label_682_f04-057.png
# There are 0 directories and 2 images in 'data\280'.
# Found image: data\280\label_683_f04-061.png
# Found image: data\280\label_684_f04-064.png
# There are 0 directories and 2 images in 'data\281'.
# Found image: data\281\label_685_f04-068.png
# Found image: data\281\label_686_f04-071.png
# There are 0 directories and 2 images in 'data\282'.
# Found image: data\282\label_687_f04-074.png
# Found image: data\282\label_688_f04-079.png
# There are 0 directories and 2 images in 'data\283'.
# Found image: data\283\label_689_f04-083.png
# Found image: data\283\label_690_f04-087.png
# There are 0 directories and 5 images in 'data\285'.
# Found image: data\285\label_691_f07-000.png
# Found image: data\285\label_692_f07-039a.png
# Found image: data\285\label_693_f07-042a.png
# Found image: data\285\label_694_f07-046a.png
# Found image: data\285\label_695_g07-079a.png
# There are 0 directories and 4 images in 'data\286'.
# Found image: data\286\label_696_f07-000b.png
# Found image: data\286\label_697_f07-002.png
# Found image: data\286\label_698_f07-006.png
# Found image: data\286\label_699_f07-009.png
# There are 0 directories and 5 images in 'data\287'.
# Found image: data\287\label_700_f07-013.png
# Found image: data\287\label_701_f07-016.png
# Found image: data\287\label_702_f07-019b.png
# Found image: data\287\label_703_f07-021b.png
# Found image: data\287\label_704_f07-024b.png
# There are 0 directories and 5 images in 'data\288'.
# Found image: data\288\label_705_f07-019a.png
# Found image: data\288\label_706_f07-021a.png
# Found image: data\288\label_707_f07-024a.png
# Found image: data\288\label_708_f07-028a.png
# Found image: data\288\label_709_f07-032a.png
# There are 0 directories and 5 images in 'data\289'.
# Found image: data\289\label_710_f07-028b.png
# Found image: data\289\label_711_f07-032b.png
# Found image: data\289\label_712_f07-036.png
# Found image: data\289\label_713_f07-039b.png
# Found image: data\289\label_714_f07-042b.png
# There are 0 directories and 1 images in 'data\290'.
# Found image: data\290\label_715_f07-046b.png
# There are 0 directories and 4 images in 'data\291'.
# Found image: data\291\label_716_f07-069.png
# Found image: data\291\label_717_f07-073.png
# Found image: data\291\label_718_f07-081b.png
# Found image: data\291\label_719_f07-084b.png
# There are 0 directories and 5 images in 'data\292'.
# Found image: data\292\label_720_f07-076a.png
# Found image: data\292\label_721_f07-081a.png
# Found image: data\292\label_722_f07-084a.png
# Found image: data\292\label_723_f07-088a.png
# Found image: data\292\label_724_f07-092a.png
# There are 0 directories and 5 images in 'data\293'.
# Found image: data\293\label_725_f07-088b.png
# Found image: data\293\label_726_f07-092b.png
# Found image: data\293\label_727_f07-096.png
# Found image: data\293\label_728_f07-101b.png
# Found image: data\293\label_729_g07-000b.png
# There are 0 directories and 4 images in 'data\294'.
# Found image: data\294\label_730_f07-101a.png
# Found image: data\294\label_731_g07-000a.png
# Found image: data\294\label_732_g07-003a.png
# Found image: data\294\label_733_g07-007a.png
# There are 0 directories and 2 images in 'data\295'.
# Found image: data\295\label_734_g01-004.png
# Found image: data\295\label_735_g01-008.png
# There are 0 directories and 3 images in 'data\296'.
# Found image: data\296\label_736_g01-012.png
# Found image: data\296\label_737_g01-016.png
# Found image: data\296\label_738_g01-019.png
# There are 0 directories and 3 images in 'data\297'.
# Found image: data\297\label_739_g01-022.png
# Found image: data\297\label_740_g01-025.png
# Found image: data\297\label_741_g01-027.png
# ...
# Found image: data\577\label_1379_n03-103.png
# There are 0 directories and 1 images in 'data\578'.
# Found image: data\578\label_1380_n03-106.png
# There are 0 directories and 1 images in 'data\579'.
# Found image: data\579\label_1381_n03-113.png
# There are 0 directories and 1 images in 'data\580'.
# Found image: data\580\label_1382_n03-120.png
# There are 0 directories and 1 images in 'data\581'.
# Found image: data\581\label_1383_n03-126.png
# There are 0 directories and 5 images in 'data\582'.
# Found image: data\582\label_1384_n04-015.png
# Found image: data\582\label_1385_n04-022.png
# Found image: data\582\label_1386_n04-031.png
# Found image: data\582\label_1387_n04-039.png
# Found image: data\582\label_1388_n04-044.png
# There are 0 directories and 5 images in 'data\583'.
# Found image: data\583\label_1389_n04-048.png
# Found image: data\583\label_1390_n04-052.png
# Found image: data\583\label_1391_n04-060.png
# Found image: data\583\label_1392_n04-068.png
# Found image: data\583\label_1393_n04-075.png
# There are 0 directories and 5 images in 'data\584'.
# Found image: data\584\label_1394_n04-084.png
# Found image: data\584\label_1395_n04-092.png
# Found image: data\584\label_1396_n04-100.png
# Found image: data\584\label_1397_n04-107.png
# Found image: data\584\label_1398_n04-114.png
# There are 0 directories and 5 images in 'data\585'.
# Found image: data\585\label_1399_n04-130.png
# Found image: data\585\label_1400_n04-139.png
# Found image: data\585\label_1401_n04-149.png
# Found image: data\585\label_1402_n04-156.png
# Found image: data\585\label_1403_n04-163.png
# There are 0 directories and 4 images in 'data\586'.
# Found image: data\586\label_1404_n04-171.png
# Found image: data\586\label_1405_n04-183.png
# Found image: data\586\label_1406_n04-190.png
# Found image: data\586\label_1407_n04-195.png
# There are 0 directories and 4 images in 'data\587'.
# Found image: data\587\label_1408_n04-202.png
# Found image: data\587\label_1409_n04-209.png
# Found image: data\587\label_1410_n04-213.png
# Found image: data\587\label_1411_n04-218.png
# There are 0 directories and 10 images in 'data\588'.
# Found image: data\588\label_1412_n06-074.png
# Found image: data\588\label_1413_n06-082.png
# Found image: data\588\label_1414_n06-092.png
# Found image: data\588\label_1415_n06-100.png
# Found image: data\588\label_1416_n06-111.png
# Found image: data\588\label_1417_n06-119.png
# Found image: data\588\label_1418_n06-123.png
# Found image: data\588\label_1419_n06-128.png
# Found image: data\588\label_1420_n06-133.png
# Found image: data\588\label_1421_n06-140.png
# There are 0 directories and 1 images in 'data\589'.
# Found image: data\589\label_1422_p01-147.png
# There are 0 directories and 1 images in 'data\590'.
# Found image: data\590\label_1423_p01-155.png
# There are 0 directories and 1 images in 'data\591'.
# Found image: data\591\label_1424_p01-168.png
# There are 0 directories and 1 images in 'data\592'.
# Found image: data\592\label_1425_p01-174.png
# There are 0 directories and 1 images in 'data\593'.
# Found image: data\593\label_1426_p02-000.png
# There are 0 directories and 1 images in 'data\594'.
# Found image: data\594\label_1427_p02-008.png
# There are 0 directories and 1 images in 'data\595'.
# Found image: data\595\label_1428_p02-017.png
# There are 0 directories and 1 images in 'data\596'.
# Found image: data\596\label_1429_p02-022.png
# There are 0 directories and 1 images in 'data\597'.
# Found image: data\597\label_1430_p02-027.png
# There are 0 directories and 2 images in 'data\598'.
# Found image: data\598\label_1431_p02-069.png
# Found image: data\598\label_1432_p02-090.png
# There are 0 directories and 2 images in 'data\599'.
# Found image: data\599\label_1433_p02-076.png
# Found image: data\599\label_1434_p02-081.png
# There are 0 directories and 1 images in 'data\600'.
# Found image: data\600\label_1435_p02-101.png
# There are 0 directories and 1 images in 'data\601'.
# Found image: data\601\label_1436_p02-105.png
# There are 0 directories and 1 images in 'data\602'.
# Found image: data\602\label_1437_p02-109.png
# There are 0 directories and 1 images in 'data\603'.
# Found image: data\603\label_1438_p02-115.png
# There are 0 directories and 1 images in 'data\604'.
# Found image: data\604\label_1439_p02-121.png
# There are 0 directories and 1 images in 'data\605'.
# Found image: data\605\label_1440_p02-127.png
# There are 0 directories and 1 images in 'data\606'.
# Found image: data\606\label_1441_p02-131.png
# There are 0 directories and 1 images in 'data\607'.
# Found image: data\607\label_1442_p02-135.png
# There are 0 directories and 1 images in 'data\608'.
# Found image: data\608\label_1443_p02-139.png
# There are 0 directories and 1 images in 'data\609'.
# Found image: data\609\label_1444_p02-144.png
# There are 0 directories and 1 images in 'data\610'.
# Found image: data\610\label_1445_p02-150.png
# There are 0 directories and 1 images in 'data\611'.
# Found image: data\611\label_1446_p02-155.png
# There are 0 directories and 1 images in 'data\612'.
# Found image: data\612\label_1447_p03-004.png
# There are 0 directories and 1 images in 'data\613'.
# Found image: data\613\label_1448_p03-009.png
# There are 0 directories and 1 images in 'data\614'.
# Found image: data\614\label_1449_p03-012.png
# There are 0 directories and 1 images in 'data\615'.
# Found image: data\615\label_1450_p03-023.png
# There are 0 directories and 1 images in 'data\616'.
# Found image: data\616\label_1451_p03-027.png
# There are 0 directories and 1 images in 'data\617'.
# Found image: data\617\label_1452_p03-029.png
# There are 0 directories and 1 images in 'data\618'.
# Found image: data\618\label_1453_p03-033.png
# There are 0 directories and 1 images in 'data\619'.
# Found image: data\619\label_1454_p03-040.png
# There are 0 directories and 1 images in 'data\620'.
# Found image: data\620\label_1455_p03-047.png
# There are 0 directories and 1 images in 'data\621'.
# Found image: data\621\label_1456_p03-069.png
# There are 0 directories and 1 images in 'data\622'.
# Found image: data\622\label_1457_p03-072.png
# There are 0 directories and 1 images in 'data\623'.
# Found image: data\623\label_1458_p03-080.png
# There are 0 directories and 1 images in 'data\624'.
# Found image: data\624\label_1459_p03-121.png
# There are 0 directories and 1 images in 'data\625'.
# Found image: data\625\label_1460_p03-135.png
# There are 0 directories and 1 images in 'data\626'.
# Found image: data\626\label_1461_p03-142.png
# There are 0 directories and 1 images in 'data\627'.
# Found image: data\627\label_1462_p03-151.png
# There are 0 directories and 1 images in 'data\628'.
# Found image: data\628\label_1463_p03-158.png
# There are 0 directories and 1 images in 'data\629'.
# Found image: data\629\label_1464_p03-163.png
# There are 0 directories and 1 images in 'data\630'.
# Found image: data\630\label_1465_p03-173.png
# There are 0 directories and 1 images in 'data\631'.
# Found image: data\631\label_1466_p03-181.png
# There are 0 directories and 1 images in 'data\632'.
# Found image: data\632\label_1467_p03-185.png
# There are 0 directories and 1 images in 'data\633'.
# Found image: data\633\label_1468_p03-189.png
# There are 0 directories and 9 images in 'data\634'.
# Found image: data\634\label_1469_p06-030.png
# Found image: data\634\label_1470_p06-042.png
# Found image: data\634\label_1471_p06-047.png
# Found image: data\634\label_1472_p06-052.png
# Found image: data\634\label_1473_p06-058.png
# Found image: data\634\label_1474_p06-069.png
# Found image: data\634\label_1475_p06-088.png
# Found image: data\634\label_1476_p06-096.png
# Found image: data\634\label_1477_p06-104.png
# There are 0 directories and 10 images in 'data\635'.
# Found image: data\635\label_1478_p06-242.png
# Found image: data\635\label_1479_p06-248.png
# Found image: data\635\label_1480_r06-000.png
# Found image: data\635\label_1481_r06-003.png
# Found image: data\635\label_1482_r06-007.png
# Found image: data\635\label_1483_r06-011.png
# Found image: data\635\label_1484_r06-018.png
# Found image: data\635\label_1485_r06-022.png
# Found image: data\635\label_1486_r06-027.png
# Found image: data\635\label_1487_r06-143.png
# There are 0 directories and 1 images in 'data\636'.
# Found image: data\636\label_1488_r02-000.png
# There are 0 directories and 1 images in 'data\637'.
# Found image: data\637\label_1489_r02-003.png
# There are 0 directories and 1 images in 'data\638'.
# Found image: data\638\label_1490_r02-006.png
# There are 0 directories and 1 images in 'data\639'.
# Found image: data\639\label_1491_r02-010.png
# There are 0 directories and 1 images in 'data\640'.
# Found image: data\640\label_1492_r02-013.png
# There are 0 directories and 1 images in 'data\641'.
# Found image: data\641\label_1493_r02-038.png
# There are 0 directories and 1 images in 'data\642'.
# Found image: data\642\label_1494_r02-054.png
# There are 0 directories and 1 images in 'data\643'.
# Found image: data\643\label_1495_r02-060.png
# There are 0 directories and 1 images in 'data\644'.
# Found image: data\644\label_1496_r02-065.png
# There are 0 directories and 1 images in 'data\645'.
# Found image: data\645\label_1497_r02-070.png
# There are 0 directories and 1 images in 'data\647'.
# Found image: data\647\label_1498_r02-078.png
# There are 0 directories and 1 images in 'data\648'.
# Found image: data\648\label_1499_r02-081.png
# There are 0 directories and 1 images in 'data\649'.
# Found image: data\649\label_1500_r02-089.png
# There are 0 directories and 1 images in 'data\650'.
# Found image: data\650\label_1501_r02-109.png
# There are 0 directories and 1 images in 'data\651'.
# Found image: data\651\label_1502_r02-117.png
# There are 0 directories and 1 images in 'data\652'.
# Found image: data\652\label_1503_r02-127.png
# There are 0 directories and 1 images in 'data\653'.
# Found image: data\653\label_1504_r02-131.png
# There are 0 directories and 1 images in 'data\654'.
# Found image: data\654\label_1505_r02-137.png
# There are 0 directories and 1 images in 'data\655'.
# Found image: data\655\label_1506_r02-146.png
# There are 0 directories and 2 images in 'data\658'.
# Found image: data\658\label_1507_r03-002.png
# Found image: data\658\label_1508_r03-007.png
# There are 0 directories and 1 images in 'data\659'.
# Found image: data\659\label_1509_r03-026.png
# There are 0 directories and 1 images in 'data\660'.
# Found image: data\660\label_1510_r03-030.png
# There are 0 directories and 1 images in 'data\661'.
# Found image: data\661\label_1511_r03-035.png
# There are 0 directories and 1 images in 'data\662'.
# Found image: data\662\label_1512_r03-050.png
# There are 0 directories and 1 images in 'data\663'.
# Found image: data\663\label_1513_r03-056.png
# There are 0 directories and 1 images in 'data\664'.
# Found image: data\664\label_1514_r03-065.png
# There are 0 directories and 1 images in 'data\665'.
# Found image: data\665\label_1515_r03-084.png
# There are 0 directories and 1 images in 'data\666'.
# Found image: data\666\label_1516_r03-090.png
# There are 0 directories and 1 images in 'data\667'.
# Found image: data\667\label_1517_r03-096.png
# There are 0 directories and 1 images in 'data\668'.
# Found image: data\668\label_1518_r03-110.png
# There are 0 directories and 1 images in 'data\669'.
# Found image: data\669\label_1519_r03-115.png
# There are 0 directories and 10 images in 'data\670'.
# Found image: data\670\label_1520_r06-035.png
# Found image: data\670\label_1521_r06-041.png
# Found image: data\670\label_1522_r06-044.png
# Found image: data\670\label_1523_r06-049.png
# Found image: data\670\label_1524_r06-053.png
# Found image: data\670\label_1525_r06-057.png
# Found image: data\670\label_1526_r06-062.png
# Found image: data\670\label_1527_r06-066.png
# Found image: data\670\label_1528_r06-070.png
# Found image: data\670\label_1529_r06-076.png
# There are 0 directories and 10 images in 'data\671'.
# Found image: data\671\label_1530_r06-090.png
# Found image: data\671\label_1531_r06-097.png
# Found image: data\671\label_1532_r06-103.png
# Found image: data\671\label_1533_r06-106.png
# Found image: data\671\label_1534_r06-111.png
# Found image: data\671\label_1535_r06-115.png
# Found image: data\671\label_1536_r06-121.png
# Found image: data\671\label_1537_r06-126.png
# Found image: data\671\label_1538_r06-130.png
# Found image: data\671\label_1539_r06-137.png
# Extracted texts: ['Text extracted from label_10_a01-049u.png', 'Text extracted from label_11_a01-049x.png', 'Text extracted from label_12_a01-053u.png', 'Text extracted from label_13_a01-058u.png', 'Text extracted from label_14_a01-063u.png', 'Text extracted from label_15_a01-068u.png', 'Text extracted from label_16_a01-072u.png', 'Text extracted from label_17_a01-077u.png', 'Text extracted from label_18_a01-082u.png', 'Text extracted from label_19_a01-087u.png', 'Text extracted from label_1_a01-000u.png', 'Text extracted from label_20_a01-091u.png', 'Text extracted from label_21_a01-096u.png', 'Text extracted from label_22_a01-102u.png', 'Text extracted from label_23_a01-107u.png', 'Text extracted from label_24_a01-113u.png', 'Text extracted from label_25_a01-117u.png', 'Text extracted from label_26_a01-122u.png', 'Text extracted from label_27_a01-128u.png', 'Text extracted from label_28_a01-132u.png', 'Text extracted from label_29_a01-132x.png', 'Text extracted from label_2_a01-003u.png', 'Text extracted from label_30_a03-050.png', 'Text extracted from label_31_a03-071.png', 'Text extracted from label_32_a03-073.png', 'Text extracted from label_33_a03-080.png', 'Text extracted from label_34_a03-089.png', 'Text extracted from label_35_a05-000.png', 'Text extracted from label_36_a05-013.png', 'Text extracted from label_37_a05-017.png', 'Text extracted from label_38_a05-022.png', 'Text extracted from label_39_a05-025.png', 'Text extracted from label_3_a01-007u.png', 'Text extracted from label_40_a05-029.png', 'Text extracted from label_41_a05-039.png', 'Text extracted from label_42_a05-044.png', 'Text extracted from label_43_a05-048.png', 'Text extracted from label_44_a05-053.png', 'Text extracted from label_45_a05-058.png', 'Text extracted from label_46_a05-062.png', 'Text extracted from label_47_a05-069.png', 'Text extracted from label_48_a05-073.png', 'Text extracted from label_49_a05-080.png', 'Text extracted from label_4_a01-011u.png', 'Text extracted from label_50_a05-084.png', 'Text extracted from label_51_a05-089.png', 'Text extracted from label_52_a05-094.png', 'Text extracted from label_53_a05-099.png', 'Text extracted from label_54_a05-104.png', 'Text extracted from label_55_a05-108.png', 'Text extracted from label_56_a05-113.png', 'Text extracted from label_57_a05-116.png', 'Text extracted from label_58_a05-121.png', 'Text extracted from label_59_a05-125.png', 'Text extracted from label_5_a01-014u.png', 'Text extracted from label_6_a01-020u.png', 'Text extracted from label_7_a01-026u.png', 'Text extracted from label_8_a01-030u.png', 'Text extracted from label_9_a01-043u.png', 'Text extracted from label_60_a01-000x.png', 'Text extracted from label_61_a01-072x.png', 'Text extracted from label_62_a01-003.png', 'Text extracted from label_63_a01-003x.png', 'Text extracted from label_64_a01-007x.png', 'Text extracted from label_65_a01-007.png', 'Text extracted from label_66_a01-011.png', 'Text extracted from label_67_a01-030.png', 'Text extracted from label_68_a01-011x.png', 'Text extracted from label_69_a01-014.png', 'Text extracted from label_70_a01-038.png', 'Text extracted from label_71_a01-014x.png', 'Text extracted from label_72_a01-026x.png', 'Text extracted from label_73_a01-020.png', 'Text extracted from label_74_a01-026.png', 'Text extracted from label_75_a01-020x.png', 'Text extracted from label_76_a01-030x.png', 'Text extracted from label_77_a01-038x.png', 'Text extracted from label_78_a01-043x.png', 'Text extracted from label_79_a01-043.png', 'Text extracted from label_80_a01-049.png', 'Text extracted from label_81_a01-053.png', 'Text extracted from label_82_a01-058.png', 'Text extracted from label_83_a01-063.png', 'Text extracted from label_84_a01-053x.png', 'Text extracted from label_85_a01-058x.png', 'Text extracted from label_86_a01-063x.png', 'Text extracted from label_87_a01-077.png', 'Text extracted from label_88_a01-091.png', 'Text extracted from label_89_a01-102.png', 'Text extracted from label_90_a0 ...

# %%
from torch.utils.data import DataLoader, Dataset
from transformers import GPT2Tokenizer

class TextDataset(Dataset):
    def __init__(self, texts, tokenizer):
        self.texts = texts
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        # Tokenize the text
        input_ids = self.tokenizer.encode(text, return_tensors="pt", padding=True, truncation=True)
        return input_ids.squeeze(0)

# Initialize tokenizer and dataset
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
dataset = TextDataset(texts, tokenizer)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)
# Out:
# C:\Users\WILSONA\anaconda3\envs\monai\lib\site-packages\huggingface_hub\file_download.py:159: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\WILSONA\.cache\huggingface\hub\models--gpt2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# C:\Users\WILSONA\anaconda3\envs\monai\lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
from transformers import GPT2LMHeadModel
import torch

# Load the GPT-2 model
model = GPT2LMHeadModel.from_pretrained("gpt2")

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Optimizer for training
optimizer = torch.optim.AdamW(model.parameters(), lr=5e-5)

# %%
# Training Loop
model.train()
num_epochs = 2  # Number of epochs

for epoch in range(num_epochs):
    total_loss = 0
    for batch in dataloader:
        inputs = batch.to(device)  # Move inputs to GPU if available
        labels = inputs.clone()
        
        optimizer.zero_grad()
        
        # Forward pass
        outputs = model(input_ids=inputs, labels=labels)
        loss = outputs.loss
        
        # Backward pass
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
    
    avg_loss = total_loss / len(dataloader)
    print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {avg_loss:.4f}")

# %%
model_save_path = "fine_tuned_gpt2"
model.save_pretrained(model_save_path)
tokenizer.save_pretrained(model_save_path)
print(f"Model saved to {model_save_path}")
